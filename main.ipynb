# %% [markdown]
# # IDML Document Migration with AI Analysis

# %% [markdown]
# ## Dependencies

# %%
from PIL import Image
from pathlib import Path
import google.genai as genai
import xml.etree.ElementTree as ET
import fitz
import json
import shutil
import mimetypes
import zipfile
import os
import re

# %%
API_KEY = 'AIzaSyBBtO2UJmUute1PJ7w3JUSEj6OLD7g7ECQ'

# %%
base_path = Path("data")
old_dir = base_path / "old"
new_template_dir = base_path / "new"
pdf_old_path = base_path / "antigo.pdf"
pdf_new_path = base_path / "new.pdf"

# Diretório de saída para o documento migrado
migrated_dir = base_path / "migrated"
idml_final_path = base_path / "migrated.idml"

# %% [markdown]
# ## PDF Document Analysis

# %% [markdown]
# ### PDF Page to Image conversion

# %%
def pdf_page_to_image(page) -> Image.Image:
    """Converte a primeira página de um PDF em um objeto de imagem."""
    pix = page.get_pixmap()
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    return img

# %% [markdown]
# ### Text Extraction

# %%
def pdf_text_extraction(page) -> list[str]:
    """Extrai todos os blocos de texto da primeira página de um PDF."""
    # Extrai texto em blocos para manter a coesão
    text_blocks = page.get_text("blocks")
    # Retorna uma lista de textos limpos
    return [block[4].replace('\n', ' ').strip() for block in text_blocks if block[4].strip()]

def pdf_text_extraction(page) -> list[str]:
    """Extrai todos os blocos de texto da primeira página de um PDF, excluindo o conteúdo de tabelas."""
    text_blocks = page.get_text("blocks")
    cleaned_texts = []
    i = 0
    while i < len(text_blocks):
        current_block_text = text_blocks[i][4].strip()
        # Check if the next block starts with "Tabelle"
        if i + 1 < len(text_blocks) and text_blocks[i + 1][4].strip().startswith("Tabelle"):
            # Skip the current block and the next block (the table caption)
            i += 2
        else:
            if current_block_text:
                cleaned_texts.append(current_block_text)
            i += 1
    return cleaned_texts

# %%
def extract_text_from_idml_story(story_file_path):
    """Extracts text content from a single IDML story XML file."""
    try:
        tree = ET.parse(story_file_path)
        root = tree.getroot()

        # print(f"Debugging IDML extraction for: {story_file_path}") # Debug print
        # print(f"Root element tag: {root.tag}") # Debug print

        # --- Namespace Handling (Adjust URI if needed) ---
        # Extract the namespace URI from the root element
        # The root tag will often be in the format {namespace_uri}local_name
        namespace_uri = None
        if root.tag.startswith('{') and '}' in root.tag:
            namespace_uri = root.tag.split('}')[0][1:]
        # -----------------------------------------------

        # print(f"Deduced Namespace URI: {namespace_uri}") # Debug print

        text_content = ""
        # Iterate through elements and extract text, using namespace if found
        for elem in root.iter(): # Iterate through all elements in the tree
            # Construct the tag name with namespace if available
            tag_to_match = elem.tag
            if namespace_uri and tag_to_match.startswith(f'{{{namespace_uri}}}'):
                 tag_to_match = tag_to_match.replace(f'{{{namespace_uri}}}', '') # Get local name


            # You might need to add other tag names here if your text is in different elements
            if tag_to_match in ['Content', 'Br']: # Consider tags likely to contain text or represent breaks
                 if elem.text:
                    text_content += elem.text
                 if tag_to_match == 'Br': # Explicitly add newline for <Br> tags
                     text_content += "\n"
                 if elem.tail: # Add tail text as it's also content
                     text_content += elem.tail


        # print(f"Extracted raw text content: '{text_content}'") # Debug print

        return text_content
    except Exception as e:
        print(f"Error extracting text from IDML story {story_file_path}: {e}")
        return None

# %%
def extract_sections(doc):
    sections = {}
    current_section_title = None
    current_section_text = ""
    section_pattern = re.compile(r'^(\d+\.\d+(\.\d+)*)') # Regex to find section numbers

    # for page_num in range(doc.page_count):
    page = doc.load_page(1)
    text = page.get_text()
    lines = text.splitlines()

    for line in lines:
        section_match = section_pattern.match(line)

        if section_match:
            # If a new section is found, save the previous one
            if current_section_title is not None:
                sections[current_section_title] = current_section_text.strip()

            current_section_title = section_match.group(1)
            current_section_text = line[section_match.end():] # Start new section text after the title
        else:
            # If no new section title, append the line to the current section's text
            current_section_text += "\n" + line

    # Save the last section after the loop
    if current_section_title is not None:
        sections[current_section_title] = current_section_text.strip()

    return sections

# %% [markdown]
# ### Image Extraction

# %%
def extract_region_from_pdf(pdf_path: str, bbox: tuple[float, float, float, float], output_folder: str):
    """Extracts an image from a specific bounding box region of each page of a PDF."""
    Path(output_folder).mkdir(parents=True, exist_ok=True)

    try:
        doc = fitz.open(pdf_path)
        for page_num in range(doc.page_count):
            page = doc.load_page(page_num)
            pix = page.get_pixmap(clip=bbox)
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
            img.save(Path(output_folder) / f"page_{page_num}_region.png")
        doc.close()
    except Exception as e:
        print(f"Error extracting region from {pdf_path}: {e}")

# %%
def extract_images_from_pdf(pdf_path: str, page_num: int, output_folder: str):
    """
    Extracts all images from a specific page of a PDF and saves them to a specified folder,
    returning a list of the saved image paths.

    Args:
        pdf_path: The path to the input PDF file.
        page_num: The page number to extract images from (0-indexed).
        output_folder: The path to the folder where extracted images will be saved.

    Returns:
        A list of paths to the saved image files, or an empty list if no images were found
        or an error occurred.
    """
    extracted_image_paths = []
    try:
        # Open the PDF document
        doc = fitz.open(pdf_path)

        # Create the output folder if it doesn't exist
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        page = doc.load_page(page_num)

        # Get a list of images on the page
        image_list = page.get_images()

        # Iterate through each image on the page
        for img_index, img_info in enumerate(image_list):
            xref = img_info[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            image_ext = base_image["ext"] # Get the image extension

            # Create the output filename
            output_filename = os.path.join(output_folder, f"page_{page_num}_img_{img_index}.{image_ext}")

            # Save the image
            with open(output_filename, "wb") as img_file:
                img_file.write(image_bytes)

            print(f"Extracted image page {page_num}, image {img_index} to {output_filename}")
            extracted_image_paths.append(output_filename) # Add the saved path to the list

        doc.close()
        print(f"Image extraction complete. Images saved to {output_folder}")
        return extracted_image_paths

    except FileNotFoundError:
        print(f"Error: PDF file not found at {pdf_path}")
        return []
    except Exception as e:
        print(f"An error occurred during image extraction: {e}")
        return []

# %% [markdown]
# ## Story Analysis

# %% [markdown]
# ### Story Text Extraction

# %%
# todo integrar essa função a análise dos textos
def story_text_extraction(story_path) -> str:
    """Extrai todo o conteúdo de texto de um arquivo de Story do IDML."""
    try:
        tree = ET.parse(story_path)
        root = tree.getroot()
        content = ""
        # Itera sobre todos os elementos de conteúdo no XML
        for content_elem in root.findall('.//Content'):
            if content_elem.text:
                content += content_elem.text
        return content.strip()
    except (ET.ParseError, FileNotFoundError):
        return ""

# %% [markdown]
# ## Text Analysis with AI

# %%
# v1
def gemini_doc_analysis(pdf_path: Path) -> dict:
    response = {}
    try:
        # 1. Preparar os dados para a análise multimodal
        doc = fitz.open(pdf_path)
        for page_num in range(doc.page_count):
            page = doc.load_page(page_num)
            textos_pdf = pdf_text_extraction(page)
            imagem_pdf = pdf_page_to_image(page)
        
            # 2. Construir o prompt para a API Gemini
            # todo especificar labels
            # todo especificar possíveis repetições
            prompt_parts = [
                "Analise a imagem desta página de documento e os textos fornecidos.",
                "Atue como um especialista em editoração eletrônica (Desktop Publishing).",
                "Para cada texto na lista, identifique seu type semântico (ex: 'title', 'subtitle', 'text_body', 'author', 'header', 'captions', 'link', 'highlighted_text', 'title_level_1', 'title_level_2', 'section_title') apenas, não analise tabelas nesse momento.",
                "Não existe números de página, pois os documentos possui navegação dinâmica com links internos.", 
                "Considere também que o título do documento, seu tipo e números de referência estão presentes em todos os slides, como parte do design, logo, só há o título de seção em todos, exceto no slide de capa.", 
                "Retorne um único objeto JSON com uma chave 'mapeamento_semantico', que contém uma lista de objetos. Cada objeto deve ter duas chaves: 'text' com o conteúdo original e 'semantic_type' com a classificação que você determinou.",
                "Seja preciso e baseie-se no layout visual (tamanho da fonte, posição, peso).",
                "\n--- IMAGEM DA PÁGINA ---",
                imagem_pdf,
                "\n--- TEXTOS EXTRAÍDOS DA PÁGINA ---",
                "\n".join(textos_pdf)
            ]

            # 3. Chamar a API Gemini
            print(f"Analisando o documento {pdf_path} ({page_num + 1}/{doc.page_count})...")
            ai = genai.Client(api_key=API_KEY)
            generation_config = {
                "temperature": 0.1,
                "response_mime_type": "application/json",
            }
            generated_content = ai.models.generate_content(contents=prompt_parts, model='gemini-1.5-flash', config=generation_config)
            response[int(page_num)] = json.loads(generated_content.text)

            print(f"\n>>> Resultado da Análise Semântica (Documento {pdf_path.name} ({page_num + 1}/{doc.page_count})):")
            print(response[int(page_num)])
            print("\n")
        doc.close()
        return response # json.loads(response)

    except Exception as e:
        print(f"❌ Ocorreu um erro ao analisar {pdf_path.name}: {e}")
        return None

# %%
# v2
def gemini_doc_analysis(pdf_old_path, pdf_new_path, idml_target_path) -> dict:
    response = {}
    try:
        old_doc = fitz.open(pdf_old_path)
        new_doc = fitz.open(pdf_new_path)

        ai = genai.Client(api_key=API_KEY)
        generation_config = {
            "temperature": 0.5,
            "response_mime_type": "application/json",
        }

        # 1. Extract text from the first page of both PDFs
        first_page_old_text = ""
        if old_doc.page_count > 0:
            first_page_old = old_doc.load_page(0)
            first_page_old_text = first_page_old.get_text()
            # print("Text from first page of old PDF:", first_page_old_text) # Debug print
            old_image_pdf = pdf_page_to_image(first_page_old)

        first_page_new_text = ""
        if new_doc.page_count > 0:
            first_page_new = new_doc.load_page(0)
            first_page_new_text = first_page_new.get_text()
            # print("Text from first page of new PDF:", first_page_new_text) # Debug print
            new_image_pdf = pdf_page_to_image(first_page_new)

        stories_dir_path = Path(idml_target_path) / 'Stories' # Assuming 'Stories' is the directory within the IDML package

        # 3. Proceed with the rest of the analysis on the potentially modified IDML files

        max_pages = max(old_doc.page_count, new_doc.page_count)

        # Extract sections from the second page onwards (using the modified extract_sections)
        old_sections = extract_sections(old_doc)
        # print("Old PDF Sections (from page 2 onwards):", old_sections) # Debug print
        new_sections = extract_sections(new_doc)
        # print("New PDF Sections (from page 2 onwards):", new_sections) # Debug print

        # Extract text from the potentially modified target IDML stories
        idml_stories_text = {}
        # Re-read the IDML files to get the updated content after replacement
        for story_file in stories_dir_path.glob("*.xml"):
            story_text = extract_text_from_idml_story(story_file)
            if story_text:
                idml_stories_text[story_file.name] = story_text
        # print("Target IDML Stories Text (after potential replacement based on first PDF page):", idml_stories_text) # Debug print

        # 4. Construir o prompt para a API Gemini with the potentially modified IDML text
        prompt_parts_first_page = [
            "You are an expert Desktop Publishing Specialist analyzing the FIRST PAGE (cover/title page) of PDF documents.",
            "Focus on identifying structural and metadata elements typical of document covers and title pages.",
            
            "FIRST PAGE ANALYSIS REQUIREMENTS:",
            "1. Focus on cover/title page elements:",
            "   - Document title and main headings",
            "   - Author information and credentials", 
            "   - Publication metadata (date, reference numbers, version)",
            "   - Institutional information (logos, affiliations)",
            "   - Abstract or summary (if present)",
            "   - Cover page formatting elements",
            
            "2. Semantic classification for first pages:",
            "   'document_title', 'subtitle', 'author', 'date', 'reference_number',",
            "   'institution', 'abstract', 'version', 'logo_text', 'cover_header',",
            "   'cover_footer', 'publication_info', 'classification_level'",
            "",
            
            "3. SPECIAL INSTRUCTION for reference_number extraction:",
            "   - Look for publication_info content that contains reference numbers",
            "   - Extract ONLY the reference number from publication info using this pattern:",
            "   - Pattern: xxx/xx/xxxx (first of sequence of 3 numbers separated by slashes)",
            "   - Example: if publication_info contains '123/45/6789 - Document Series - 2024'",
            "   - Then reference_number should be: '123'",
            "   - Always separate reference_number from other publication_info content",
            
            "4. Match criteria:",
            "   - Elements match if they serve the same structural purpose on the cover",
            "   - Focus on document identification and metadata correspondence",
            "   - Consider visual hierarchy typical of title pages",
            "   - For reference_number: extract the xxx/xx/xxxx pattern from publication_info",
            
            "OUTPUT FORMAT:",
            "Return JSON with 'mapeamento_semantico' containing objects with:",
            "- 'semantic_type': specific semantic classification",
            "- 'old_text': content from original PDF (null if not found)",
            "- 'new_text': content from template PDF (null if not found)",
            "- 'idml_text': relevant IDML content (null if not found)", 
            "- 'match': boolean indicating semantic correspondence",
            
            "CONTENT TO ANALYZE:",
            "\\n--- ORIGINAL PDF PAGE IMAGE ---\\n",
            old_image_pdf if old_image_pdf else "No image available",
            "\\n--- ORIGINAL PDF TEXT ---\\n",
            json.dumps(first_page_old_text, ensure_ascii=False) if first_page_old_text else "No text found",
            "\\n--- TEMPLATE PDF PAGE IMAGE ---\\n", 
            new_image_pdf if new_image_pdf else "No image available",
            "\\n--- TEMPLATE PDF TEXT ---\\n",
            json.dumps(first_page_new_text, ensure_ascii=False) if first_page_new_text else "No text found",
            "\\n--- IDML CONTENT ---\\n",
            json.dumps(idml_stories_text, ensure_ascii=False) if idml_stories_text else "No IDML content"
        ]

        # 5. Chamar a API Gemini
        print(f"Analisando os documentos (Página 0)...")
        
        try:
            generated_content = ai.models.generate_content(contents=prompt_parts_first_page, model='gemini-2.0-flash', config=generation_config)
            response[0] = json.loads(generated_content.text)
            print(f">>> Resultado da Análise Semântica (Página 0):")
            print(json.dumps(response[0], indent=2, ensure_ascii=False))
        except Exception as e:
            print(f"❌ Ocorreu um erro ao analisar a página 0: {e}")
            response[0] = {"error": str(e)}

        for page_num in range(1, max_pages):
            page_from_old = None
            page_from_new = None
            old_image_pdf = None
            new_image_pdf = None
            old_page_text = ""
            new_page_text = ""

            if page_num < old_doc.page_count:
                page_from_old = old_doc.load_page(page_num)
                old_image_pdf = pdf_page_to_image(page_from_old)
                old_page_text = page_from_old.get_text()

            if page_num < new_doc.page_count:
                page_from_new = new_doc.load_page(page_num)
                new_image_pdf = pdf_page_to_image(page_from_new)
                new_page_text = page_from_new.get_text()

            # 4. Construir o prompt para a API Gemini with the potentially modified IDML text
            prompt_parts = [
                "Acting as a Desktop Publishing Specialist, analyze the provided images, text from two PDF documents, and text content from target IDML files.",
                "Compare the content and semantic structure of corresponding pages in the two PDF documents, focusing on the provided section context (which starts from the second page). Also consider the text content from the target IDML files (which may have been modified based on the first page of the PDFs) for additional context and comparison.",
                "For each text element, identify its semantic type (e.g: 'title', 'subtitle', 'text_body', 'author', 'header', 'captions', 'link', 'highlighted_text', 'title_level_1', 'title_level_2', 'section_title'). Do not analyze tables at this time.",
                "In addition to identifying semantic types and matches, please analyze and identify text elements that appear to be repeated or very similar across the old and new PDF documents on this page, even if they are not exact matches or don't require substitution. Label these with a 'repeated_or_similar' key with a boolean value (true if repeated/similar, false otherwise).",
                "There are no page numbers, as the documents have dynamic navigation with internal links. The PDF document is page 0 based.",
                "Also consider standardizations such as repetition of terms across pages, such as the document title in a smaller font, its type in a stronger font, and reference number.",
                "Return a single JSON object with a main key 'mapeamento_semantico', containing a list of objects.",
                "Each object in the list should represent a semantic element and have the following keys: 'semantic_type', 'old_text' (content from the original PDF document section, or null if not found in the section), 'new_text' (content from the template PDF document section, or null if not found in the section), 'idml_text' (relevant content from the target IDML files, or null), 'match' (booleano indicating if the semantic type exists in both PDF documents within the corresponding section and is consistent with the IDML text, even if the text is completely different, always prioritizing the semantic type), and 'repeated_or_similar' (boolean indicating if the text element appears to be repeated or very similar across the old and new PDF documents on this page).",
                "If any of the extractions return a null value for old_text, new_text, or idml_text for a given semantic type, mark the match as false.",
                "CONTENT TO ANALYZE:",
                "\\n--- ORIGINAL PDF PAGE IMAGE ---\\n",
                old_image_pdf if old_image_pdf else "No image available",
                "\\n--- ORIGINAL PDF FULL TEXT ---\\n",
                json.dumps(old_page_text, ensure_ascii=False) if old_page_text else "No text found",
                "\\n--- ORIGINAL PDF SECTIONS (context) ---\\n",
                json.dumps(old_sections, ensure_ascii=False) if old_sections else "No sections found",
                "\\n--- TEMPLATE PDF PAGE IMAGE ---\\n",
                new_image_pdf if new_image_pdf else "No image available", 
                "\\n--- TEMPLATE PDF FULL TEXT ---\\n",
                json.dumps(new_page_text, ensure_ascii=False) if new_page_text else "No text found",
                "\\n--- TEMPLATE PDF SECTIONS (context) ---\\n",
                json.dumps(new_sections, ensure_ascii=False) if new_sections else "No sections found",
                "\\n--- IDML CONTENT (for reference) ---\\n",
                json.dumps(idml_stories_text, ensure_ascii=False) if idml_stories_text else "No IDML content"
            ]

            # 5. Chamar a API Gemini
            print(f"Analisando os documentos (Página {page_num})...")
            
            try:
                generated_content = ai.models.generate_content(contents=prompt_parts, model='gemini-2.0-flash', config=generation_config)
                response[page_num] = json.loads(generated_content.text)
                response[page_num]["mapeamento_semantico"].extend(response[0]["mapeamento_semantico"])
                print(f">>> Resultado da Análise Semântica (Página {page_num}):")
                print(json.dumps(response[page_num], indent=2, ensure_ascii=False))
            except Exception as e:
                print(f"❌ Ocorreu um erro ao analisar a página {page_num}: {e}")
                response[page_num] = {"error": str(e)}

        old_doc.close()
        new_doc.close()
        return response

    except Exception as e:
        print(f"❌ Ocorreu um erro ao realizar a análise: {e}")
        return None

# %% [markdown]
# ## Image Analysis with AI

# %%
def ai_doc_image_analysis(pdf_old_path: str, pdf_new_path: str) -> dict:
    """
    Analyzes and compares images on each page of two PDF documents using Gemini.

    Args:
        pdf_old_path: The path to the original PDF file.
        pdf_new_path: The path to the new PDF file.

    Returns:
        A dictionary containing the image analysis results for each page,
        or None if an error occurred.
    """
    response = {}
    try:
        # Open the PDF documents
        old_doc = fitz.open(pdf_old_path)
        new_doc = fitz.open(pdf_new_path)

        # Ensure both documents have the same number of pages for comparison
        if old_doc.page_count != new_doc.page_count:
            print("Warning: Documents have different page counts. Comparison will be limited.")
            # Decide how to handle this: compare up to the minimum number of pages, or raise an error
            # For now, we'll compare up to the minimum number of pages
            num_pages = min(old_doc.page_count, new_doc.page_count)
        else:
            num_pages = old_doc.page_count

        for page_num in range(num_pages):
            page_from_old = old_doc.load_page(page_num)
            page_from_new = new_doc.load_page(page_num)

            old_image_pdf = pdf_page_to_image(page_from_old)
            new_image_pdf = pdf_page_to_image(page_from_new)

            # Build the prompt for the Gemini API
            prompt_parts = [
                "Act as an image analysis expert. Compare the images provided from two PDF documents, page by page.",
                "Identify and describe the images present on each page.",
                "Compare the images on the corresponding pages of the two documents.",
                "Note any differences or similarities in the images, including their content, position, size, or style.",
                "For each page, provide a summary of the image comparison.",
                "Return a single JSON object with a key 'image_analysis' and the value is an object containing:",
                "'old_images': A list of descriptions of images found on the old document's page, or null if no images.",
                "'new_images': A list of descriptions of images found on the new document's page, or null if no images.",
                "'comparison_summary': A text summary of the comparison between the images on this page.",
                "'action': 'migrate' when the description is similar enough to replace in the new design and 'non-migrate' when it is not necessary to replace"
                "\n--- IMAGE FROM OLD DOCUMENT PAGE ---",
                old_image_pdf if old_image_pdf else "No image for old document on this page.",
                "\n--- IMAGE FROM NEW DOCUMENT PAGE ---",
                new_image_pdf if new_image_pdf else "No image for new document on this page."
            ]

            # Call the Gemini API
            print(f"Analyzing images on page {page_num}...")
            ai = genai.Client(api_key=API_KEY)
            generation_config = {
                "temperature": 0.1,
                "response_mime_type": "application/json",
            }
            try:
                generated_content = ai.models.generate_content(
                    contents=prompt_parts,
                    model='gemini-2.0-flash', # Or another suitable model
                    config=generation_config
                )
                response[page_num] = json.loads(generated_content.text)
                print(f">>> Image Analysis Result (Page {page_num + 1}):")
                print(json.dumps(response[page_num], indent=2, ensure_ascii=False))
            except Exception as e:
                print(f"❌ An error occurred while analyzing images on page {page_num + 1}: {e}")
                response[page_num] = {"error": str(e)}

        old_doc.close()
        new_doc.close()
        return response

    except FileNotFoundError:
        print("Error: One or both PDF files not found.")
        return None
    except Exception as e:
        print(f"❌ An error occurred during image analysis: {e}")
        return None

# %% [markdown]
# ## Execution

# %% [markdown]
# ### Text

# %%
analysis_result = gemini_doc_analysis(pdf_old_path, pdf_new_path, new_template_dir)
# Out:
# Analisando os documentos (Página 0)...
# >>> Resultado da Análise Semântica (Página 0):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 1)...
# >>> Resultado da Análise Semântica (Página 1):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": null,
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Beschreibung & Vorteile",
#       "new_text": "Beschreibung & Vorteile",
#       "idml_text": "Beschreibung & Vorteile\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Positionierung & Kunden",
#       "new_text": "Positionierung & Kunden",
#       "idml_text": "Positionierung & Kunden\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Produktdaten & Bestellinformation",
#       "new_text": "Produktdaten & Bestellinformation",
#       "idml_text": "Produktdaten & Bestellinformation\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": null,
#       "new_text": "Kommunikationsmedien zur \nVertriebsunterstützung",
#       "idml_text": "Kommunikationsmedien zurVertriebsunterstützung\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Mitbewerberinformationen",
#       "new_text": "Mitbewerberinformationen",
#       "idml_text": "Mitbewerberinformationen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Verpackung & Gebrauchshinweis",
#       "new_text": "Verpackung & Gebrauchshinweis",
#       "idml_text": "Verpackung & Gebrauchshinweis\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Hintergrundinformationen & Literatur",
#       "new_text": "Hintergrundinformationen & Literatur",
#       "idml_text": "Hintergrundinformationen & Literatur\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Produktbeschreibung /  \n\t\nZweckbestimmung",
#       "new_text": "Produktbeschreibung / Zweckbestimmung",
#       "idml_text": "1.1\tProduktbeschreibung / Zweckbestimmung\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Eigenschaften und Vorteile",
#       "new_text": "Eigenschaften, Vorteile & Nutzen",
#       "idml_text": "1.2\tEigenschaften, Vorteile & Nutzen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Übersicht Kundenkreis und \n\t\nSchlagwörter",
#       "new_text": "Kundenkreis",
#       "idml_text": "2.1\tKundenkreis\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": null,
#       "new_text": "Schlagwörter",
#       "idml_text": "2.2 Schlagwörter\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": null,
#       "new_text": "Positionierung",
#       "idml_text": "2.3 Positionierung\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": null,
#       "new_text": "Potential",
#       "idml_text": "2.4 Potential\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Produktdaten und  \n\t\nBestellinformation",
#       "new_text": "Produktdaten & Bestellinformation",
#       "idml_text": "3.1\tProduktdaten und Bestellinformationen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Webseite",
#       "new_text": "Webseite",
#       "idml_text": "4.1 Webseite\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": null,
#       "new_text": "Mediaportal",
#       "idml_text": "4.2\tMediaportal\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": null,
#       "new_text": "Public (P:)",
#       "idml_text": "4.3 Public (P:)\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Allgemeine Informationen zu \n\t\nMitbewerbern",
#       "new_text": "Allgemeine Informationen zu Mitbewerbern",
#       "idml_text": "5.1\tAllgemeine Informationen zu Mitbewerbern\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Artikelvergleichsliste",
#       "new_text": "Artikelvergleichsliste",
#       "idml_text": "5.2\tArtikelvergleichsliste\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Eigenschaften & Vorteile \n\t\nMitbewerberprodukte",
#       "new_text": "Eigenschaften und Vorteile Mitbewerberprodukte",
#       "idml_text": "5.3\tEigenschaften und Vorteile Mitbewerberprodukte\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Verpackung",
#       "new_text": "Verpackung",
#       "idml_text": "6.1 Verpackung\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Gebrauchshinweis",
#       "new_text": "Gebrauchshinweis",
#       "idml_text": "6.2\tGebrauchshinweis\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Sicherheitsdatenblatt (MSDS)",
#       "new_text": "Sicherheitsdatenblatt",
#       "idml_text": "6.3\tSicherheitsdatenblätter\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": null,
#       "new_text": "Konformitätserklärungen",
#       "idml_text": "6.4\tKonformitätserklärungen\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Hintergrundinformationen",
#       "new_text": "Hintergrundinformationen",
#       "idml_text": "7.1 Hintergrundinformationen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 2)...
# >>> Resultado da Análise Semântica (Página 2):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "I.I Was wird geändert?",
#       "new_text": "1.1\tProduktbeschreibung / Zweckbestimmung",
#       "idml_text": "1.1\tProduktbeschreibung / Zweckbestimmung\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Unsere CryoPure Röhren sind nun zusätzlich als DNA-/DNase- und RNase-frei zertfiziert.",
#       "new_text": "Kleinvolumige automatisierbare Blutentnahmeröhrchen bieten eine innovative Lösung für die Vermeidung von unnötigem labordiagnostischen Blutverlust bei z.B. Intensivpatienten und auf der anderen Seite eine schnellere Befundung pädiatri-\nscher Blutproben durch Wegfall manueller Laborschritte.",
#       "idml_text": "Kleinvolumige automatisierbare Blutentnahmeröhrchen\n\t\t\t bieten eine innovative Lösung für die Vermeidung von unnötigem labordiagnostischen Blutverlust bei z.B. Intensivpatienten und auf der anderen Seite eine schnellere Befundung pädiatrischer Blutproben durch Wegfall manueller Laborschritte.\n\t\t\t\t\n",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "I.II Änderungsgrund",
#       "new_text": "1.2\tEigenschaften, Vorteile & Nutzen",
#       "idml_text": "1.2\tEigenschaften, Vorteile & Nutzen\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Die Änderung ist Folge von erhöhter Nachfrage nach DNA-/DNase- und RNase-freien \nKryokonservierungsgefäßen und zur Verhinderung von Kundenabwanderung. Zell- und \nGewebeproben dürfen bei der „vitalen“ Konservierung in CryoPure Röhren keinen\nzusätzlichen Risiken hinsichtlich Kontaminationen mit störenden Stoffen ausgesetzt werden. \nDurch erweiterte Testung und erfolgreiche Zertifizierung bei gleichen Produktionsbedingungen \nkönnen wir unseren Kunden garantieren, weitere Störfaktoren nachweislich minimiert zu haben.",
#       "new_text": "Folgende Eigenschaften zeichnen beide S-Monovetten (S-Monovette® 1.6 ml Serum CAT  und S-Monovette® Lithium \nHeparin LH) aus:",
#       "idml_text": "Folgende Eigenschaften zeichnen beide S-Monovetten (S-Monovette\n\t\t\t®\n\t\t\t 1.6 ml Serum CAT  und S-Monovette\n\t\t\t®\n\t\t\t Lithium Heparin LH) aus:\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "I.III Verfügbarkeit",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "DNA-/DNase- und RNase-freie CryoPure Röhren sind ab LOT 3081421 verfügbar.\nSie werden nach Abverkauf des Altbestandes des jeweiligen Artikels verfügbar sein.",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "I.IV Produktdaten und Bestellinformation neu",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Es erfolgt keine Änderung der Artikelnummern. Alle Produktdaten finden sich in Abschnitt 3.1 \n\"Produktdaten und Bestellinformationen\".",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "trademark",
#       "old_text": null,
#       "new_text": "S-Monovette®",
#       "idml_text": "S-Monovette\n\t\t\t®\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_2",
#       "old_text": null,
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": null,
#       "new_text": "Beschreibung & Vorteile",
#       "idml_text": "Beschreibung & Vorteile\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 3)...
# >>> Resultado da Análise Semântica (Página 3):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "1.1 Produktbeschreibung / Zweckbestimmung",
#       "new_text": "1.2.1\t\n Vorteile & Nutzen für den Einsatz in der Pädiatrie",
#       "idml_text": "1.2\tEigenschaften, Vorteile & Nutzen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "CryoPure Gefäße werden in vier verschiedenen Ausführungen angeboten, welche sich in \nihrem Fassungsvermögen oder Schraubdeckelfarbe unterscheiden (siehe Abbildung 1). \nAlle Gefäße bestehen aus einem klaren Kunststoffgefäß mit Rundboden und sind mit \neinem Schraubverschluss versehen, wobei drei Varianten mit Außengewinde und eine \nVariante mit Innengewinde und Silikondichtring erhältlich sind. Alle Röhren besitzen ein \nSchriftfeld und eine eindeutige Kennzeichnung der Nennfüllmenge. \nIn die Schraubverschlüsse können sogenannte Codierplättchen in unterschiedlichen \nFarben eingedrückt werden um eine Probenkodierung zu ermöglichen.\nCryoPure Gefäße sind Einweggefäße für die Lagerung und Kryokonservierung von festen \nund flüssigen, biologischen Proben (z.B. Gewebe) bei Temperaturen bis -196°C. CryoPure \nGefäße sind in der Gasphase des flüssigen Stickstoffs zu lagern. Die Anwendung darf \nausschließlich durch entsprechend geschultes Fachpersonal erfolgen.",
#       "new_text": "Im folgenden werden 4 Szenarien beschrieben, für die ein Wechsel vorteilhaft ist.",
#       "idml_text": "Im folgenden werden 3 Szenarien beschrieben, für die ein Wechsel vorteilhaft ist.\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "repeated_or_similar",
#       "old_text": "Produktbeschreibung / Zweckbestimmung",
#       "new_text": "Produktbeschreibung / Zweckbestimmung",
#       "idml_text": "1.1\tProduktbeschreibung / Zweckbestimmung\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "repeated_or_similar",
#       "old_text": "Nur zum internen Gebrauch",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 4)...
# >>> Resultado da Análise Semântica (Página 4):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "1.2 Eigenschaften & Vorteile",
#       "new_text": null,
#       "idml_text": "1.2\tEigenschaften, Vorteile & Nutzen\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Innen- und Außengewinde\n\t•\nSARSTEDT bietet hochtransparenten CryoPure Röhren mit verschiedenen Fassungsvolumina und \nGewindetypen an.\n\t• Um das Kontaminationsrisiko minimieren zu können, stehen CryoPure Röhren mit sicherem \nAußengewinde und Nennvolumina von 1,8 ml bis 4,5 ml zur Verfügung .\n\t• Um die Lagerdichte auf ein 10 x 10 Raster erhöhen zu können, sind außerdem CryoPure Röhren \nmit Innengewinde und Silikondichtring mit einem Nennvolumen von 1,6 ml verfügbar.",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Ergonomischer Verschluss\n\t•\nDurch den QuickSeal Verschlussmechanismus ist ein sicheres Öffnen und Schließen beider \nVerschlusstypen mit nur einer Umdrehung gewährleistet.",
#       "new_text": "33% mehr",
#       "idml_text": "33 % mehr\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Farbcodierung\n\t•\nDurch die Kombination von 6 verschiedenfarbigen Kappen mit 6 verschiedenfarbigen Codierplättchen \nergeben sich bis zu 36 Farbkombinationen zur visuellen Kodierung und einfachen Identifizierung der \nProben.",
#       "new_text": "23% mehr",
#       "idml_text": "23 % mehr\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Exemplarisch sind die hier abgebildeten S-Monovetten und  \nMicro-Probengefäße im EU Farbcode vorgestellt:  \n \nArt.-Nr.: 06.1663.001, 41.1503.005, 41.1501.005, 04.2911.001\n \nDie Artikel-Nummern der entsprechenden S-Monovetten und  \nMicro-Probengefäße im ISO Farbcode sind:  \n \nArt.-Nr.: 06.1663.100, 41.1503.105, 41.1501.105, 04.1501.105",
#       "idml_text": "Exemplarisch sind \n\t\t\tdie hier abgebildeten S-Monovetten und Micro-Probengefäße\n\t\t\t im \n\t\t\tEU Farbcode\n\t\t\t vorgestellt: Art.-Nr.: 06.1663.001, 41.1503.005, 41.1501.005, 04.2911.001\n\t\t\t\t\n\n\t\t\t\t\n\n\t\t\t\t\n\n\t\t\t\tDie Artikel-Nummern der entsprechenden S-Monovetten und Micro-Probengefäße im \n\t\t\tISO Farbcode\n\t\t\t sind: Art.-Nr.: 06.1663.100, 41.1503.105, 41.1501.105, 04.1501.105\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 5)...
# >>> Resultado da Análise Semântica (Página 5):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Beschreibung & Vorteile",
#       "new_text": "Beschreibung & Vorteile",
#       "idml_text": "Beschreibung & Vorteile\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Positionierung & Kunden",
#       "new_text": "Positionierung & Kunden",
#       "idml_text": "Positionierung & Kunden\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Produktdaten &\nBestellinformation",
#       "new_text": "Produktdaten & Bestellinformation",
#       "idml_text": "Produktdaten & Bestellinformation\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Marketingmaterialien",
#       "new_text": "Kommunikationsmedien zur \nVertriebsunterstützung",
#       "idml_text": "Kommunikationsmedien zur Vertriebsunterstützung\n\t\t\t",
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Mitbewerber- \ninformationen",
#       "new_text": "Mitbewerberinformationen",
#       "idml_text": "Mitbewerberinformationen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Verpackung &\nGebrauchshinweis",
#       "new_text": "Verpackung & Gebrauchshinweis",
#       "idml_text": "Verpackung & Gebrauchshinweis\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Hintergrund- \ninform. & Literatur",
#       "new_text": "Hintergrundinformationen & Literatur",
#       "idml_text": "Hintergrundinformationen & Literatur\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Graduierung und Beschriftung",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "• Zur visuellen Volumenkontrolle sind CryoPure Röhren graduiert. Außerdem verfügen sie über ein weißes \nBeschriftungsfeld.",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Optimales Design",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "• Die optimale Innenkontur des Gefäßbodens der CryoPure Röhren erleichtert eine rückstandslose \nProbenentnahme.\n• Der Standfuß ist freistehend konzipiert.\n• Der Standfuß der CryoPure Röhren ermöglicht im CryoRack 40 und den meisten anderen \nhandelsüblichen Arbeitsständern eine bequeme Einhandbedienung der Röhren.",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_1",
#       "old_text": "Cryo Performance Tested",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "• Zell- und Gewebeproben dürfen bei der „vitalen“ Konservierung in CryoPure Röhren keinen \nzusätzlichen Risiken hinsichtlich Kontaminationen mit störenden Stoffen ausgesetzt werden.  Folgende \nReinheitskriterien werden durch ein unabhängiges Labor zertifiziert:",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "✓Steril",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Gemäß ISO 11137",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "✓Pyrogenfrei/endotoxinfrei",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "<0,06 EU/ml",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "✓Nicht-zytotoxisch",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "In Übereinstimmung mit ISO 10993-5",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "✓Nicht-mutagen",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Der Nachweis zur Abschätzung der Mutagenitätsfreiheit \nwurde nach dem Ames Test II durchgeführt",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "✓DNA-frei",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Humane DNA <0,5 pg/μl, bakterielle DNA <0,02 pg/μl",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "✓DNase/RNase-frei",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "DNase <1x10-5 U/μl, RNase <1x10-9 Kunitz-units/μl",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "Produktänderung",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "Produktinformation",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_2",
#       "old_text": null,
#       "new_text": "1.2.2 Vorteile & Nutzen bei der Umsetzung des Patient Blood Management (PBM) Konzeptes",
#       "idml_text": "1.2.2\t Vorteile & Nutzen bei der Umsetzung des Patient Blood Management (PBM) Konzeptes\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Im folgenden werden 3 Szenarien beschrieben, für die ein Wechsel vorteilhaft ist.",
#       "idml_text": "Im folgenden werden 3 Szenarien beschrieben, für die ein Wechsel vorteilhaft ist.\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Szenario",
#       "idml_text": "Szenario\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Zielgruppe",
#       "idml_text": "Zielgruppe\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Vorteil für das Krankenhauslabor",
#       "idml_text": "Vorteil für das Krankenhauslabor\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Vorteil für den Anwender auf der Station",
#       "idml_text": "Vorteil für den Anwender auf der Station\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Vorteil für den Patienten",
#       "idml_text": "Vorteil für den Patienten\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "1",
#       "idml_text": "1\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "SARSTEDT Kunde:\nWechsel / Ergänzung 4,9 ml / 2,7 ml  \nauf 1,6 ml S-Monovette®",
#       "idml_text": "SARSTEDT Kunde:\n\t\t\t\t\t\t\t\t\t\t\t\n\n\t\t\t\t\t\t\t\t\t\t\tWechsel / Ergänzung 4,9 ml / 2,7 ml auf 1,6 ml S-Monovette\n\t\t\t\t\t\t\t\t\t\t®\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Imageprojekt PBM / Patientenwohl / Wertigkeit Blutprobe / kostbares Probenmaterial\n■Weniger krankenhausassoziierte Anämien aufgrund geringerer Probenvolumina (vor allem auf der Intensivstation (ITS)) und \ndamit geringerem labordiagnostischen Blutverlust. Dadurch resultieren geringere Kosten durch weniger Blutkonserven.\n■Stetige Prozessoptimierung / -überprüfung: Entspricht aktuelles Probenvolumen noch dem Anforderungsprofil / -verhalten?\n■Nachhaltiger durch geringere Entsorgungskosten aufgrund geringerem Blutvolumen / -gewichtes und reduziertem Kunst-\nstoffeinsatzes",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Imageprojekt PBM / Patientenwohl / Wertigkeit Blutprobe / kostbares Probenmaterial\n■Schnellere Blutentnahme aufgrund geringerem Blutvolumen\n■Weniger Komplikationen aufgrund weniger krankenhausassoziierter Anämien\n■Weniger Transfusionen aufgrund reduziertem labordiagnostischen Blutverlust auf der \nITS\n■Geringere Kosten durch geringeren Bedarf an Blutkonserven",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Besseres Wohlbefinden / geringere Patientenbelastung  \naufgrund  \n- weniger krankenhausassoziierter Anämien  \n- weniger Transfusionen  \n- weniger Transfusionskomplikationen \n \nGilt vor allem für Patienten auf der Intensivstation",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "2",
#       "idml_text": "2\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Mitbewerber:\ngroßvolumige Vakuum-Röhrchen",
#       "idml_text": "Mitbewerber:\n\t\t\t\t\t\t\t\t\t\t\t\n\n\t\t\t\t\t\t\t\t\t\t\tgroßvolumige Vakuum-Röhrchen\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Imageprojekt PBM / Patientenwohl / Wertigkeit Blutprobe / kostbares Probenmaterial\n■Potentiell weniger hämolytische Proben in kritischen Bereichen wie Notaufnahme, ITS\n■Geringere Kosten durch weniger Blutkonserven aufgrund bewussterem Umgang mit Blutkonserven\n■Nachhaltiger durch geringere Entsorgungskosten aufgrund geringerem Blutvolumen /  \n-gewichtes und reduziertem Kunststoffeinsatzes",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Imageprojekt PBM / Patientenwohl / Wertigkeit Blutprobe / kostbares Probenmaterial\n■Schonende Blutentnahme mit der Aspirationstechnik der S-Monovette® gewährleistet\n■Kollabieren der Vene vorgebeugt\n■Schnellerer Befund im Fall kollabierter Venen / wiederholter Blutentnahmen \n■Schnellere Blutentnahme aufgrund geringerem Blutvolumen\n■Weniger Komplikationen aufgrund weniger krankenhausassoziierter Anämien\n■Weniger Transfusionen aufgrund reduziertem labordiagnostischen Blutverlust auf der \nIntensivstation (ITS))\n■Geringere Kosten durch geringeren Bedarf an Blutkonserven",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Besseres Wohlbefinden / geringere Patientenbelastung \naufgrund  \n- weniger krankenhausassoziierter Anämien  \n- weniger Transfusionen \n- weniger Transfusionskomplikationen\n\n■Besseres Wohlbefinden aufgrund potentiell weniger  \nkollabierter Venen / wiederholter Blutentnahmen",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "3",
#       "idml_text": "3\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "Mitbewerber:\nkleinvolumige Vakuum-Röhrchen  \n(low volume / low vacuum; 1 ml, 2 ml)",
#       "idml_text": "Mitbewerber:\n\t\t\t\t\t\t\t\t\t\t\t\n\n\t\t\t\t\t\t\t\t\t\t\tkleinvolumige Vakuum-Röhrchen (low volume / low vacuum; 1 ml, 2 ml)\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Gilt für 1 ml low volume Vakuumröhrchen, wenn mehrere Analyte daraus bestimmt werden:\n■Wegfall folgender Schritte im Krankenhauslabor: \n- das Abpipettieren von Serum / Plasma nach Zentrifugation und Überführen in (zuvor manuell etikettierte)  \nSekundärgefäße\n■Minimierung der Vertauschungsgefahr von Probenmaterial durch Wegfall des Schrittes Überführen in Sekundärgefäß\n■Zeitgewinn für sinnvollere / andere Labortätigkeiten",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Schnelles Befüllen gewährleistet \n- Low-volume (low-vacuum) Röhrchen befüllen sich aufgrund des niedrigen Unterdrucks \n(Vakuums) langsam\n■Schonende Entnahme mit der Aspirationstechnik gewährleistet\n■Schnellerer Befund und schnellere Therapieentscheidung dank kürzerer TAT im Labor\n■Einfachere Logistik dank längere Produkthaltbarkeit",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": null,
#       "new_text": "■Bei kleinvolumigen Vakuum-Röhrchen weniger häufig: \n \nBesseres Wohlbefinden aufgrund potentiell weniger  \nkollabierter Venen / wiederholter Blutentnahmen",
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "highlighted_text",
#       "old_text": null,
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title",
#       "old_text": null,
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title",
#       "old_text": null,
#       "new_text": "990",
#       "idml_text": "990\n\t\t\t",
#       "match": true,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
# ...
#       "new_text": "Beschreibung & Vorteile",
#       "idml_text": "Beschreibung & Vorteile",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Positionierung & Kunden",
#       "new_text": "Positionierung & Kunden",
#       "idml_text": "Positionierung & Kunden",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Produktdaten & Bestellinformation",
#       "new_text": "Produktdaten & Bestellinformation",
#       "idml_text": "Produktdaten & Bestellinformation",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Marketingmaterialien",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Mitbewerber- informationen",
#       "new_text": "Mitbewerberinformationen",
#       "idml_text": "Mitbewerberinformationen",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Verpackung & Gebrauchshinweis",
#       "new_text": "Verpackung & Gebrauchshinweis",
#       "idml_text": "Verpackung & Gebrauchshinweis",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "Hintergrund- inform. & Literatur",
#       "new_text": "Hintergrundinformationen & Literatur",
#       "idml_text": "Hintergrundinformationen & Literatur",
#       "match": true,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_2",
#       "old_text": "6.2 Gebrauchshinweis",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "title_level_2",
#       "old_text": "6.3 Sicherheitsdatenblatt (MSDS)",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 18)...
# >>> Resultado da Análise Semântica (Página 18):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "6.2 Gebrauchshinweis",
#       "new_text": "Gebrauchshinweis",
#       "idml_text": "Gebrauchshinweis",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "link",
#       "old_text": "https://www.sarstedt.com/download/gebrauchshinweise/",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "6.3 Sicherheitsdatenblatt (MSDS)",
#       "new_text": "Sicherheitsdatenblatt",
#       "idml_text": "Sicherheitsdatenblätter",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Gemäß der derzeit gültigen Verordnung (EG) 1907/2006 sind für Erzeugnisse und für als nicht gefährlich eingestufte Gemische keine Sicherheitsdatenblätter erforderlich.",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "repeated_text",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "repeated_text",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Produktänderung",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Beschreibung & Vorteile",
#       "new_text": "Beschreibung & Vorteile",
#       "idml_text": "Beschreibung & Vorteile",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Positionierung & Kunden",
#       "new_text": "Positionierung & Kunden",
#       "idml_text": "Positionierung & Kunden",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Produktdaten & Bestellinformation",
#       "new_text": "Produktdaten & Bestellinformation",
#       "idml_text": "Produktdaten & Bestellinformation",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Marketingmaterialien",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Mitbewerber- informationen",
#       "new_text": "Mitbewerberinformationen",
#       "idml_text": "Mitbewerberinformationen",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Verpackung & Gebrauchshinweis",
#       "new_text": "Verpackung & Gebrauchshinweis",
#       "idml_text": "Verpackung & Gebrauchshinweis",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "header",
#       "old_text": "Hintergrund- inform. & Literatur",
#       "new_text": "Hintergrundinformationen & Literatur",
#       "idml_text": "Hintergrundinformationen & Literatur",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }
# Analisando os documentos (Página 19)...
# >>> Resultado da Análise Semântica (Página 19):
# {
#   "mapeamento_semantico": [
#     {
#       "semantic_type": "title",
#       "old_text": "Produktänderung CryoPure Röhren",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "7.1 Hintergrundinformationen",
#       "new_text": "Hintergrundinformationen & Literatur",
#       "idml_text": "7.1 Hintergrundinformationen",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "title_level_2",
#       "old_text": "Lagerung von SARSTEDT CryoPure Röhren in flüssigem Stickstoff",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Bei unsachgemäßem Gebrauch, wenn das CryoPure Gefäß in der Flüssigphase des Stickstoffs gelagert wird, kann flüssiger Stickstoff\nin die Röhre eindringen und die Probe kontaminieren, da sich durch die sinkenden Temperaturen ein Unterdruck in der Röhre bildet.\nDer eingedrungene Stickstoff würde beim Auftauen der Probe in die Gasphase übergehen und einen erhöhten Innendruck erzeugen,\nder zur Explosion und Freisetzung von infektiösem Material führen kann.",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "Folgende Sicherheitsmaßnahmen sollten beim Umgang mit Flüssigstickstoff immer eingehalten werden:",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "text_body",
#       "old_text": "• CryoPure Gefäße nur in der Gasphase von Flüssigstickstoff lagem.\n• CryoPure Gefäße bis zur Nennmarkierung füllen. Über- oder Unterfüllung erhöht das Kontaminations- und Explosionsrisiko.\n• CryoPure Gefäße handfest zudrehen, nicht überdrehen und keine Hilfsmittel benutzen.\n• Persönliche Schutzausrüstung tragen. Flüssigstickstoff kann u.a. Kälteverbrennungen, Erfrierungen sowie schwere\nAugenschädigungen hervorrufen.\n• CryoPure Gefäße in einem abgedeckten Behälter (z. B. Wasserbad) auftauen.",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "section_title",
#       "old_text": "7.2 Literatur",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": false
#     },
#     {
#       "semantic_type": "footer",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": null,
#       "idml_text": "Nur zum internen Gebrauch",
#       "match": false,
#       "repeated_or_similar": true
#     },
#     {
#       "semantic_type": "document_title",
#       "old_text": "CryoPure Röhren",
#       "new_text": "Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH",
#       "idml_text": "Kleinvolumige S-Monovette\n\t\t\t®\n\t\t\t 1,6 ml Serum CAT / Lithium-Heparin LH\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "subtitle",
#       "old_text": "Produktinformation 958 / 72 / 0823",
#       "new_text": "Produktinformation",
#       "idml_text": "Produktinformation\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "author",
#       "old_text": "Susanne Bäß, Produktmanagement Life Science",
#       "new_text": "Dr. Christa Seipelt, Produktmanagerin Präanalytik",
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "date",
#       "old_text": null,
#       "new_text": "März 2025",
#       "idml_text": "März 2025\n\t\t\t",
#       "match": false
#     },
#     {
#       "semantic_type": "reference_number",
#       "old_text": "958",
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "institution",
#       "old_text": "www.sarstedt.com",
#       "new_text": null,
#       "idml_text": null,
#       "match": true
#     },
#     {
#       "semantic_type": "abstract",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "version",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "logo_text",
#       "old_text": "SARSTEDT",
#       "new_text": "SARSTEDT",
#       "idml_text": "SARSTEDT\n\t\t\t\t\t\t\t\t\t\tBezeichnung",
#       "match": true
#     },
#     {
#       "semantic_type": "cover_header",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "cover_footer",
#       "old_text": "+++ Nur zum internen Gebrauch +++",
#       "new_text": "Nur zum internen Gebrauch",
#       "idml_text": "Nur zum internen Gebrauch\n\t\t\t",
#       "match": true
#     },
#     {
#       "semantic_type": "publication_info",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     },
#     {
#       "semantic_type": "classification_level",
#       "old_text": null,
#       "new_text": null,
#       "idml_text": null,
#       "match": false
#     }
#   ]
# }

# %%
migration_plan = {}

# %%
# Iterate through the pages in the analysis result

migration_plan = {}
for page_num, page_data in analysis_result.items():
    migration_plan[page_num] = []  # Initialize migration plan for this page

    # Get the semantic mapping for the current page
    semantic_map_page = page_data.get('mapeamento_semantico', [])

    # Iterate through the semantic elements on the page
    for item in semantic_map_page:
        if item.get('match') and not item.get('repeated_or_similar'):
            migration_plan[page_num].append({
                "type": item.get('semantic_type'),
                "conteudo_a_migrar": item.get('old_text'),
                "placeholder": item.get('new_text'),
                "match": item.get('match'),
                "notes": f"Match status: {item.get('match')}" # Add a note about the match status
            })

# Example of how to use the migration_plan:
for page_num, page_migration_items in migration_plan.items():
    print(f"Migration plan for page {page_num + 1}:")
    for item in page_migration_items:
        print(f"Tipo: [{item['type']}] - Substituir '{item['placeholder']}' por '{item['conteudo_a_migrar']}'")
    print()
# Out:
# Migration plan for page 1:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 2:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [title_level_1] - Substituir 'Kundenkreis' por 'Übersicht Kundenkreis und
#
# Schlagwörter'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 3:
# Tipo: [title_level_2] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'None'
# Tipo: [subtitle] - Substituir 'Beschreibung & Vorteile' por 'None'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 4:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [section_title] - Substituir '1.2.1
#  Vorteile & Nutzen für den Einsatz in der Pädiatrie' por '1.1 Produktbeschreibung / Zweckbestimmung'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 5:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 6:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [title_level_2] - Substituir '1.2.2 Vorteile & Nutzen bei der Umsetzung des Patient Blood Management (PBM) Konzeptes' por 'None'
# Tipo: [text_body] - Substituir 'Im folgenden werden 3 Szenarien beschrieben, für die ein Wechsel vorteilhaft ist.' por 'None'
# Tipo: [text_body] - Substituir 'Szenario' por 'None'
# Tipo: [text_body] - Substituir 'Zielgruppe' por 'None'
# Tipo: [text_body] - Substituir 'Vorteil für das Krankenhauslabor' por 'None'
# Tipo: [text_body] - Substituir 'Vorteil für den Anwender auf der Station' por 'None'
# Tipo: [text_body] - Substituir 'Vorteil für den Patienten' por 'None'
# Tipo: [text_body] - Substituir '1' por 'None'
# Tipo: [text_body] - Substituir 'SARSTEDT Kunde:
# Wechsel / Ergänzung 4,9 ml / 2,7 ml
# auf 1,6 ml S-Monovette®' por 'None'
# Tipo: [text_body] - Substituir '2' por 'None'
# Tipo: [text_body] - Substituir 'Mitbewerber:
# großvolumige Vakuum-Röhrchen' por 'None'
# Tipo: [text_body] - Substituir '3' por 'None'
# Tipo: [text_body] - Substituir 'Mitbewerber:
# kleinvolumige Vakuum-Röhrchen
# (low volume / low vacuum; 1 ml, 2 ml)' por 'None'
# Tipo: [title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'None'
# Tipo: [title] - Substituir '990' por 'None'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 7:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [section_title] - Substituir '2.1 Kundenkreis' por '2.1 Übersicht Kundenkreis und Schlagwörter'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 8:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 9:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [header] - Substituir 'Farbcode' por 'Farbe
# Schraubver-
# schluss'
# Tipo: [header] - Substituir 'Volumen [ml]' por 'Nennfüll-
# menge'
# Tipo: [text_body] - Substituir 'S-Monovette® 1,6 ml
# Serum CAT' por 'CryoPure 5,0 ml Röhren mit
# Außengewinde'
# Tipo: [text_body] - Substituir '1,6' por '4,5 ml'
# Tipo: [text_body] - Substituir 'EU' por 'Außengewinde'
# Tipo: [text_body] - Substituir 'S-Monovette® 1,6 ml
# Serum CAT' por 'CryoPure 5,0 ml Röhren mit
# Außengewinde'
# Tipo: [text_body] - Substituir '1,6' por '4,5 ml'
# Tipo: [text_body] - Substituir 'EU' por 'Außengewinde'
# Tipo: [text_body] - Substituir 'S-Monovette® 1,6 ml
# Serum CAT' por 'CryoPure 5,0 ml Röhren mit
# Außengewinde'
# Tipo: [text_body] - Substituir '1,6' por '4,5 ml'
# Tipo: [text_body] - Substituir 'ISO' por 'Außengewinde'
# Tipo: [text_body] - Substituir 'S-Monovette® 1,6 ml
# Lithium-Heparin LH' por 'CryoPure 2,0 ml Röhren mit
# Innengewinde und Silikondichtring'
# Tipo: [text_body] - Substituir '1,6' por '1,6 ml'
# Tipo: [text_body] - Substituir 'EU' por 'Innengewinde'
# Tipo: [text_body] - Substituir 'S-Monovette® 1,6 ml
# Lithium-Heparin LH' por 'CryoPure 2,0 ml Röhren mit
# Innengewinde und Silikondichtring'
# Tipo: [text_body] - Substituir '1,6' por '1,6 ml'
# Tipo: [text_body] - Substituir 'EU' por 'Innengewinde'
# Tipo: [text_body] - Substituir 'S-Monovette® 1,6 ml
# Lithium-Heparin LH' por 'CryoPure 2,0 ml Röhren mit
# Innengewinde und Silikondichtring'
# Tipo: [text_body] - Substituir '1,6' por '1,6 ml'
# Tipo: [text_body] - Substituir 'ISO' por 'Innengewinde'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 10:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [title_level_1] - Substituir '4.1	Webseite' por 'None'
# Tipo: [title_level_1] - Substituir '4.2	Mediaportal' por 'None'
# Tipo: [title_level_1] - Substituir '4.3	Public (P:)' por 'None'
# Tipo: [text_body] - Substituir 'Alle auf der Webseite und im Mediaportal integrierten Kampagnen-Inhalte finden Sie auch lokal unter:
# P:\Marketing\Marketing campaigns\Go for Gold' por 'None'
# Tipo: [link] - Substituir 'WEBSEITE' por 'None'
# Tipo: [link] - Substituir 'MEDIAPORTAL' por 'None'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 11:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 12:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 13:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [section_title] - Substituir '6.1	Verpackung' por 'None'
# Tipo: [section_title] - Substituir '6.2	Gebrauchshinweis' por 'None'
# Tipo: [section_title] - Substituir '6.3	Sicherheitsdatenblätter' por 'None'
# Tipo: [section_title] - Substituir '6.4	Konformitätserklärungen' por 'None'
# Tipo: [text_body] - Substituir 'Alle Sicherheitsdatenblätter finden Sie' por 'None'
# Tipo: [text_body] - Substituir 'Alle Konformitätserklärungen finden Sie' por 'None'
# Tipo: [text_body] - Substituir 'Oder scannen Sie ganz einfach den QR Code (www.sarstedt.com/s-monovette) auf dem Innenkarton ein.
# Die Kurzanleitung befindet sich im Deckel des Innenkartons.' por 'None'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 14:
# Tipo: [title] - Substituir 'Produktinformation' por 'Produktänderung CryoPure Röhren'
# Tipo: [header] - Substituir 'Hintergrundinformationen & Literatur' por 'None'
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 15:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 16:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 17:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 18:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 19:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'
#
# Migration plan for page 20:
# Tipo: [document_title] - Substituir 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' por 'CryoPure Röhren'
# Tipo: [subtitle] - Substituir 'Produktinformation' por 'Produktinformation 958 / 72 / 0823'
# Tipo: [author] - Substituir 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' por 'Susanne Bäß, Produktmanagement Life Science'
# Tipo: [institution] - Substituir 'None' por 'www.sarstedt.com'
# Tipo: [logo_text] - Substituir 'SARSTEDT' por 'SARSTEDT'
# Tipo: [cover_footer] - Substituir 'Nur zum internen Gebrauch' por '+++ Nur zum internen Gebrauch +++'

# %% [markdown]
# ### Image

# %%
# Example usage:
analysis_results = ai_doc_image_analysis(pdf_old_path, pdf_new_path)
if analysis_results:
    # Process the analysis_results dictionary
    print("Image analysis completed successfully.")
# Out:
# Warning: Documents have different page counts. Comparison will be limited.
# Analyzing images on page 0...
# >>> Image Analysis Result (Page 1):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a product advertisement for CryoPure Röhren. It features several test tubes with different colored caps, arranged in a row. The tubes appear to contain a red liquid. The Sarstedt logo is visible in the bottom right corner."
#     ],
#     "new_images": [
#       "The image shows a product advertisement for Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH. It features several test tubes with different colored caps, arranged in a row. The tubes appear to contain a red liquid. The Sarstedt logo is visible in the top left corner."
#     ],
#     "comparison_summary": "The old image shows CryoPure Röhren test tubes, while the new image shows Kleinvolumige S-Monovette® test tubes. Both images feature a row of test tubes with different colored caps and a red liquid inside. The Sarstedt logo is present in both images, but in different locations. The overall style and purpose of the images are similar, both serving as product advertisements.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 1...
# >>> Image Analysis Result (Page 2):
# {
#   "image_analysis": {
#     "old_images": [
#       "A table of contents with a gray house icon on the left and the Sarstedt logo on the bottom right."
#     ],
#     "new_images": [
#       "A table of contents with arrows between the sections and the Sarstedt logo on the top left."
#     ],
#     "comparison_summary": "The images are both tables of contents for a document. The old image has a gray house icon and the Sarstedt logo on the bottom right. The new image has arrows between the sections and the Sarstedt logo on the top left. The content of the tables is similar, but the layout and design are different.",
#     "action": "migrate"
#   }
# }
# Analyzing images on page 2...
# >>> Image Analysis Result (Page 3):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image appears to be a promotional page for CryoPure Röhren (CryoPure Tubes) from Sarstedt. It includes the Sarstedt logo, a navigation bar at the top with sections like 'Produktänderung' (Product Change), 'Beschreibung & Vorteile' (Description & Advantages), etc. The main content describes the features and benefits of the CryoPure tubes, highlighting that they are DNA-/DNAse- and RNAse-free certified. There's also a 'Cryo Performance Tested' badge with certifications listed. The bottom of the page includes the Sarstedt website address and a note indicating 'Nur zum internen Gebrauch' (For internal use only)."
#     ],
#     "new_images": [
#       "The image is a product information page, likely from Sarstedt, featuring 'kleinvolumige S-Monovette' (small-volume S-Monovette) tubes. The page includes the Sarstedt logo and a product information header. The main content describes the features, benefits, and applications of the S-Monovette tubes, including their use in pediatric settings and for blood management. There are bullet points listing key characteristics such as 'kleinvolumig' (small-volume) and 'Standardmaße' (standard dimensions). The page also includes an image of the S-Monovette tubes. The bottom of the page includes a note indicating 'Nur zum internen Gebrauch' (For internal use only)."
#     ],
#     "comparison_summary": "The old document page promotes CryoPure tubes, focusing on their DNA/RNA-free certification and suitability for cryopreservation. The new document page promotes small-volume S-Monovette tubes, highlighting their use in pediatric settings and blood management. The images are completely different in terms of product and application.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 3...
# >>> Image Analysis Result (Page 4):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a product page for CryoPure tubes. It includes text in German describing the product's features and applications. There is a diagram illustrating four different configurations of the CryoPure tubes. The page also includes company logos and navigation elements."
#     ],
#     "new_images": null,
#     "comparison_summary": "The old document page contains an image of a product page for CryoPure tubes, including product descriptions and diagrams. The new document page does not contain any images.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 4...
# >>> Image Analysis Result (Page 5):
# {
#   "image_analysis": {
#     "old_images": [
#       "A product presentation page with text in German, featuring multiple images of CryoPure tubes with different colored caps. The images are used to illustrate the product's features, such as the different volumes and color-coding options. The page also includes the Sarstedt logo."
#     ],
#     "new_images": [
#       "A product information page with the Sarstedt logo, featuring images of S-Monovette tubes with different fill levels and colored caps. The images are used to illustrate the product's features and variations. The page also includes text in German describing the product and its article numbers."
#     ],
#     "comparison_summary": "The old document shows CryoPure tubes, while the new document shows S-Monovette tubes. Both documents use images to showcase product features, but the products themselves are different. The Sarstedt logo is present in both.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 5...
# >>> Image Analysis Result (Page 6):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a product information page for CryoPure tubes from Sarstedt. It includes the product name, a diagram of the tube, and text describing the features and benefits of the product. There are also several logos and certifications displayed."
#     ],
#     "new_images": [
#       "The image shows a product information page for Sarstedt, focusing on the benefits and uses of Patient Blood Management (PBM) concepts. It is structured as a table with scenarios, target groups, advantages for the application site, and advantages for the patient. The page includes text descriptions and the Sarstedt logo."
#     ],
#     "comparison_summary": "The old image is a product information page for CryoPure tubes, while the new image is a product information page about Patient Blood Management (PBM) concepts. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 6...
# >>> Image Analysis Result (Page 7):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image is a table with the title 'Tabelle 2 nennt Einrichtungen und Schlagwörter, die bei der Identifizierung von Kunden helfen' (Table 2 lists facilities and keywords that help in identifying customers). The table has columns for 'Einrichtung' (Facility), 'Richtung allgemein' (General direction), 'Richtung speziell / Institute' (Specific direction / Institute), and 'Schlagwörter' (Keywords). The table lists various types of facilities such as 'Ärzte' (Doctors), 'Diagnostische Labore' (Diagnostic Laboratories), 'Industrie' (Industry), 'Krankenhäuser' (Hospitals), 'Universitäten' (Universities), and 'Universitätskliniken' (University Hospitals) along with their corresponding directions and keywords."
#     ],
#     "new_images": [
#       "The image shows four different sizes of S-Monovette tubes filled with varying amounts of a red liquid, presumably blood. The tubes are labeled with their respective volumes: 7.5 ml, 4.0 ml, 2.7 ml, and 1.6 ml. Each tube has a percentage indicating how much less liquid it contains compared to the 7.5 ml tube. The percentages are 40%, 64%, and 78% less, respectively. The tubes are also labeled with 'Serum CAT/Z/7ml'. Below the tubes, there are some text descriptions in German, including article numbers and information about ISO Farbcode (ISO color code)."
#     ],
#     "comparison_summary": "The old image is a table describing customer identification, while the new image shows different sizes of blood collection tubes. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 7...
# >>> Image Analysis Result (Page 8):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image is a table displaying product information for CryoPure tubes. It includes columns for product number, description, color coding, nominal volume, type, sterile status, pyrogen/cytotoxin status, DNase/RNase free status, material (tube/cap), holding capacity (vials), packaging, and availability date. The table lists various CryoPure tube specifications with different volumes and color codings. The bottom of the image contains the Sarstedt logo and a disclaimer: '+++ Nur zum internen Gebrauch +++'."
#     ],
#     "new_images": [
#       "The image displays product information and positioning details from Sarstedt. It includes sections on customer base (Kunden), contact persons (Ansprechpartner), key words (Schlagwörter), product positioning (Produktpositionierung), and potential applications (Potential). The image contains text descriptions of each section, highlighting the benefits and applications of Sarstedt products. The Sarstedt logo is prominently displayed at the top left, and a disclaimer '+++ Nur zum internen Gebrauch +++' is at the bottom right."
#     ],
#     "comparison_summary": "The old image is a product table, while the new image is a marketing and positioning overview. The images are completely different in content and purpose. The old image provides technical specifications, while the new image focuses on customer benefits and applications.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 8...
# >>> Image Analysis Result (Page 9):
# {
#   "image_analysis": {
#     "old_images": [
#       "A table displaying product information for CryoPure tubes, including details such as part number, description, color, volume, sterility, and packaging. The table has a header row with categories like 'Produktänderung', 'Beschreibung & Vorteile', 'Positionierung & Kunden', 'Produktdaten & Bestellinformation', 'Marketingmaterialien', 'Mitbewerber-Informationen', 'Verpackung & Gebrauchshinweis', and 'Hintergrund-Inform. & Literatur'. The table rows contain specific product attributes, with plus signs indicating positive attributes and circles indicating color options. The table is part of a document with the title 'Produktänderung CryoPure Röhren'."
#     ],
#     "new_images": [
#       "A table displaying product information for 'S-Monovette' products, including details such as product name, properties, volume, color, sterility, and packaging. The table has a header row with categories like 'Bezeichnung', 'Produkteigenschaften', 'Volumen (ml)', 'Farbcodes', 'Etikett', 'CE', 'Steril', 'Haltbarkeit* (Monate)', 'Latex-frei', 'Zertifizierung', 'Zentrifugationsbedingungen und Gerinnungszeit', 'Blutprobe nach Entnahme über Kopf schwenken', 'Verpackung (Stk/VE/Karton)', and 'Verfügbar ab'. The table rows contain specific product attributes, with checkmarks indicating positive attributes and 'IVD' indicating 'In-vitro diagnostic' certification. The table is part of a document with the title 'Produktinformation' and the subtitle 'Kleinvolumige S-Monovette® 1.6 ml Serum CAT / Lithium-Heparin LH'."
#     ],
#     "comparison_summary": "Both images contain tables displaying product information. The old image focuses on 'CryoPure Röhren' products, while the new image focuses on 'S-Monovette' products. Both tables include details about product properties, sterility, and packaging, but the specific attributes and categories differ. The layout and design of the tables are also different, reflecting different branding and presentation styles.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 9...
# >>> Image Analysis Result (Page 10):
# {
#   "image_analysis": {
#     "old_images": [
#       "A table displaying product and ordering information for coder plates, including columns for order number, color, weight, material, shelf life, packaging, and availability date.",
#       "A table displaying product and ordering information for CryoRack 40/workstations, including columns for order number, capacity, packaging, and availability date.",
#       "A photograph of various colored tubes in a rack, likely related to the products described in the tables.",
#       "The Sarstedt logo."
#     ],
#     "new_images": [
#       "The Sarstedt logo.",
#       "A photograph of a person using a laptop, with a graphic on the screen showing data and the text 'Proven millions of times over, safe and efficient!' and 'The Industry standard'.",
#       "A photograph of a woman in the background."
#     ],
#     "comparison_summary": "The old document page contains tables with product information and a product photograph, while the new document page features a person using a laptop displaying a graphic, a woman in the background, and the Sarstedt logo. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 10...
# >>> Image Analysis Result (Page 11):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a table with product and ordering information for cryoboxes. The table has columns for part number, suitable for cryovials, grid size, storage capacity, outer dimensions, material, color, packaging, VE (packaging unit), and available since. There is also an image of cryovials in cryoboxes on the right side of the image."
#     ],
#     "new_images": [
#       "The image shows a table with competitor information. The table has columns for product name, color code, barcode, part number, and company name. The companies listed are Sarstedt, Greiner Bio-One, KIMA, and KABE."
#     ],
#     "comparison_summary": "The old image shows a table of cryobox product information, while the new image shows a table of competitor information. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 11...
# >>> Image Analysis Result (Page 12):
# {
#   "image_analysis": {
#     "old_images": [
#       "A product page with the title 'Produktanderung CryoPure Rohren'. It contains a table with product information, including a brochure titled 'Zell- und Gewebekultur' (Cell and tissue culture). There is an image of a cell culture flask with the text 'Come Grow With Us'."
#     ],
#     "new_images": [
#       "A product information page with a table comparing the features and benefits of different competitor products. The product is 'Kleinvolumige S-Monovette' 1.6 ml Serum CAT / Lithium-Heparin LH'."
#     ],
#     "comparison_summary": "The old image is a product page focusing on CryoPure tubes and cell culture brochures, while the new image is a product information page comparing S-Monovette products with competitors. The content and focus are different.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 12...
# >>> Image Analysis Result (Page 13):
# {
#   "image_analysis": {
#     "old_images": [
#       "A product information page with a table listing CryoPure freezing system information in multiple languages, along with a product image showing tubes and a freezing system."
#     ],
#     "new_images": [
#       "Illustrations of packaging options (Umverpackung, Innenkarton, Umkarton, Palette) with corresponding quantities of S-Monovette products. Also includes a QR code and detailed diagrams with instructions."
#     ],
#     "comparison_summary": "The old document shows a product information page with a table and product image related to the CryoPure freezing system. The new document shows packaging options and diagrams with instructions for S-Monovette products. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 13...
# >>> Image Analysis Result (Page 14):
# {
#   "image_analysis": {
#     "old_images": [
#       "Image of a CryoPure Musterset, a product from Sarstedt, displayed in a box with various colored tubes. The image is on the left side of the page, accompanied by text in German."
#     ],
#     "new_images": null,
#     "comparison_summary": "The old document page contains an image of a Sarstedt product, while the new document page does not contain any images. Therefore, the images are completely different.",
#     "action": "non-migrate"
#   }
# }
# Image analysis completed successfully.

# %%
# Example Usage:
# Assuming 'analysis_result' is the output from ai_doc_image_analysis
image_migration_plan = build_image_migration_plan(analysis_results)
print(image_migration_plan)

# Print the generated image migration plan
for page_num, migration_items in image_migration_plan.items():
    print(f"Image Migration Plan for Page {page_num + 1}:")
    if migration_items:
        for item in migration_items:
            print(f"- Action: {item.get('action')}")
            print(f"  Old Image: {item.get('old_image_description')}")
            if item.get('action') == 'replace_image':
                print(f"  New Image Target: {item.get('new_image_description')}")
            elif item.get('action') == 'insert_image':
                 print(f" Target Location Notes: {item.get('target_location_notes')}")
            print(f"  Notes: {item.get('notes')}")
    else:
        print("  No image migration needed for this page.")
    print()
# Out:
# {}

# %% [markdown]
# ## Content Replacement

# %% [markdown]
# ### Text Replacement

# %%
def get_content_text_from_element(element):
    text = ""
    for sub_element in element.iter():
        if sub_element.tag == 'Content' and sub_element.text:
            text += sub_element.text
    return text

# %%
def replace_and_consolidate_content(placeholder: str, novo_conteudo: str, stories_path: Path) -> bool:
    """Encontra o arquivo de story que contém o placeholder e substitui seu conteúdo."""
    for story_file in stories_path.glob("*.xml"):
        try:
            # Usar um parser que lida com namespaces é uma boa prática
            parser = ET.XMLParser(encoding="utf-8")
            tree = ET.parse(story_file, parser=parser)
            root = tree.getroot()

            # Flag para indicar se houve modificação no arquivo
            arquivo_modificado = False

            # Encontra todos os ParagraphStyleRange elements
            for paragraph_style_range in root.findall('.//ParagraphStyleRange'):
                
                # Usa a função para obter texto combinado de tags <Content> no parágrafo
                combined_content_text = get_content_text_from_element(paragraph_style_range)

                # Verifica se o texto combinado contém o placeholder
                if placeholder in combined_content_text:
                    print(f"   -> Encontrado placeholder '{placeholder}' em '{story_file.name}'. Substituindo...")
                    
                    # --- Lógica de Substituição e Consolidação ---
                    
                    # Encontra todos os CharacterStyleRange elements no parágrafo
                    char_style_ranges_in_paragraph = paragraph_style_range.findall('.//CharacterStyleRange')
                    
                    # Encontra a sequência de CharacterStyleRange que contém o placeholder
                    sequence_found = False
                    sequence_start_index = -1
                    sequence_end_index = -1
                    current_combined_sequence_text = ""
                    elements_to_remove = []

                    for i, char_style_range in enumerate(char_style_ranges_in_paragraph):
                        content_text_in_char_style = get_content_text_from_element(char_style_range)
                        
                        # Verifica se estamos construindo a sequência correta
                        if (placeholder.startswith(current_combined_sequence_text + content_text_in_char_style) or 
                            current_combined_sequence_text == ""):
                            
                            if sequence_start_index == -1:
                                sequence_start_index = i
                            current_combined_sequence_text += content_text_in_char_style
                            
                            # Se encontramos o placeholder completo na sequência
                            if placeholder in current_combined_sequence_text:
                                sequence_end_index = i
                                sequence_found = True
                                break
                        else:
                            # Reset se a sequência não corresponde
                            current_combined_sequence_text = ""
                            sequence_start_index = -1
                            sequence_end_index = -1

                    if sequence_found:
                        # Identifica os elementos para remover
                        elements_to_remove = char_style_ranges_in_paragraph[sequence_start_index:sequence_end_index + 1]
                        insertion_point_index = sequence_start_index

                        # Lista dos filhos diretos do paragraph_style_range
                        children_to_process = list(paragraph_style_range)
                        removed_count = 0

                        # Remove os elementos identificados
                        for child in children_to_process:
                            if child in elements_to_remove:
                                paragraph_style_range.remove(child)
                                removed_count += 1

                        # Ajusta o ponto de inserção baseado nos elementos removidos
                        insertion_point_index = max(0, insertion_point_index - removed_count)

                        # Cria o novo CharacterStyleRange consolidado
                        new_char_style_range = ET.Element('CharacterStyleRange')
                        
                        # Copia os atributos do primeiro elemento removido (se existir)
                        if elements_to_remove:
                            for attr, value in elements_to_remove[0].items():
                                new_char_style_range.set(attr, value)

                        # Adiciona o novo conteúdo, tratando quebras de linha
                        linhas = novo_conteudo.split('\n')
                        for i, linha in enumerate(linhas):
                            if i > 0:
                                ET.SubElement(new_char_style_range, 'Br')
                            content_tag = ET.SubElement(new_char_style_range, 'Content')
                            content_tag.text = linha

                        # Insere o novo elemento no ponto calculado
                        paragraph_style_range.insert(insertion_point_index, new_char_style_range)
                        
                        arquivo_modificado = True
                        print(f"    * Substituído e consolidado: '{placeholder}' -> '{novo_conteudo}'")
                    else:
                        print(f"    # Não foi possível encontrar a sequência de CharacterStyleRange contendo '{placeholder}'")

            # Salva as alterações se o arquivo foi modificado
            if arquivo_modificado:
                tree.write(story_file, encoding="UTF-8", xml_declaration=True)
                return True  # Modificação bem-sucedida

        except Exception as e:
            print(f"   -> Erro ao processar o arquivo {story_file.name}: {e}")
    
    return False  # Placeholder não encontrado em nenhuma story

# %%
# antigo
def encontrar_e_substituir_na_story(placeholder: str, novo_conteudo: str, stories_path: Path) -> bool:
    """Encontra o arquivo de story que contém o placeholder e substitui seu conteúdo."""
    for story_file in stories_path.glob("*.xml"):
        try:
            # Usar um parser que lida com namespaces é uma boa prática
            parser = ET.XMLParser(encoding="utf-8")
            tree = ET.parse(story_file, parser=parser)
            root = tree.getroot()

            # Precisamos verificar se o placeholder está no arquivo antes de modificar
            raw_text = ET.tostring(root, encoding='unicode')
            if placeholder not in raw_text:
                continue

            # Encontra o elemento de parágrafo/estilo que contém o placeholder
            # todo ajustar para quando houver quebra de linha
            for elem in root.findall('.//ParagraphStyleRange//CharacterStyleRange'):
                content_tags = elem.findall('Content')
                # Recria o texto dentro da tag de estilo para uma busca precisa
                current_text = "".join([c.text for c in content_tags if c.text])
                
                if placeholder in current_text:
                    print(f"   -> Encontrado placeholder em '{story_file.name}'. Substituindo...")
                    
                    # Limpa o conteúdo antigo (tags <Content> e <Br />)
                    for sub_elem in list(elem):
                        if sub_elem.tag in ['Content', 'Br']:
                            elem.remove(sub_elem)
                    
                    # Adiciona o novo conteúdo, tratando quebras de linha
                    linhas = novo_conteudo.split('\n')
                    for i, linha in enumerate(linhas):
                        if i > 0:
                            ET.SubElement(elem, 'Br')
                        content_tag = ET.SubElement(elem, 'Content')
                        content_tag.text = linha
                    
                    # Salva as alterações no arquivo XML
                    tree.write(story_file, encoding="UTF-8", xml_declaration=True)
                    return True # Modificação bem-sucedida

        except Exception as e:
            print(f"   -> Erro ao processar o arquivo {story_file.name}: {e}")
    
    return False # Placeholder não encontrado em nenhuma story

# %%
# 6. Executar a migração
# Primeiro, crie uma cópia limpa do template para modificação
if os.path.exists(migrated_dir):
    print(f"🧹 Limpando diretório de migração anterior: '{migrated_dir}'")
    shutil.rmtree(migrated_dir)

print(f"©️ Copiando template de '{new_template_dir}' para '{migrated_dir}'...")
shutil.copytree(new_template_dir, migrated_dir)

# Agora, aplique as modificações na cópia
print("✍️  Iniciando a substituição de conteúdo nos arquivos de Story...")
stories_path_migrado = migrated_dir / "Stories"
sucessos = 0
for index in migration_plan.keys():
    for item in migration_plan[index]:
        if replace_and_consolidate_content(item['placeholder'], item['conteudo_a_migrar'], stories_path_migrado):
            sucessos += 1

if sucessos > 0:
    print(f"✅ {sucessos} substituições de conteúdo realizadas com sucesso.")
else:
    print("⚠️ Nenhuma substituição de conteúdo foi realizada. Verifique os placeholders.")
# Out:
# ©️ Copiando template de 'data/new' para 'data/migrated'...
# ✍️  Iniciando a substituição de conteúdo nos arquivos de Story...
#    -> Encontrado placeholder 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' em 'Story_u172.xml'. Substituindo...
#     * Substituído e consolidado: 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' -> 'CryoPure Röhren'
#    -> Encontrado placeholder 'Produktinformation' em 'Story_u67d.xml'. Substituindo...
#     # Não foi possível encontrar a sequência de CharacterStyleRange contendo 'Produktinformation'
#    -> Encontrado placeholder 'Produktinformation' em 'Story_u15c.xml'. Substituindo...
#     * Substituído e consolidado: 'Produktinformation' -> 'Produktinformation 958 / 72 / 0823'
#    -> Encontrado placeholder 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' em 'Story_u1b0.xml'. Substituindo...
#     * Substituído e consolidado: 'Dr. Christa Seipelt, Produktmanagerin Präanalytik' -> 'Susanne Bäß, Produktmanagement Life Science'
#    -> Erro ao processar o arquivo Story_ue90.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3a2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u852.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u868.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1c6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub0d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u90c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u212.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud1c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udec.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u336.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2e6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1f4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u67d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc80.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u63e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1dc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u748.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u58d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua10.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua68.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua26.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u498.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u894.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf5d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue20.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u93f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9b3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u75e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc58.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u482.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9fa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u805.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u798.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u146.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u533.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u426.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u54a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7ca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue37.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue7a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud72.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u654.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uef6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u922.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u60f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u352.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf1e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub31.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucc4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2cc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5b9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uae1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uba3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u96d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u628.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4db.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u560.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uebe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6b7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u83c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u31c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u87e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub5f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u172.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue03.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u983.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue4d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u262.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub76.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud56.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u36c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua3c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u456.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u700.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud06.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufcd.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u576.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud32.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u22c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufa0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8aa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4ae.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u507.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u386.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u955.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaa2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u193.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf8a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u99d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u27c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubfe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucf0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u440.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc97.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub8d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u246.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u15c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufb7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1b0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8c0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7e1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ueda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ube6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5a3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubb9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udd6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud89.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5f9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf74.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4f1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaf7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6e9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5d1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc34.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6d3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7b4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua52.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u296.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9ce.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u51d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4c4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubd0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3bc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u774.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u302.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uff1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uea6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3f2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2b2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u46c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf46.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3d6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue64.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc1a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u724.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u822.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u40c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u69e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua7e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Encontrado placeholder 'SARSTEDT' em 'Story_ucc4.xml'. Substituindo...
#     * Substituído e consolidado: 'SARSTEDT' -> 'SARSTEDT'
#    -> Encontrado placeholder 'SARSTEDT' em 'Story_ucc4.xml'. Substituindo...
#     * Substituído e consolidado: 'SARSTEDT' -> 'SARSTEDT'
#    -> Encontrado placeholder 'Nur zum internen Gebrauch' em 'Story_u1f4.xml'. Substituindo...
#     * Substituído e consolidado: 'Nur zum internen Gebrauch' -> '+++ Nur zum internen Gebrauch +++'
#    -> Encontrado placeholder 'Produktinformation' em 'Story_u67d.xml'. Substituindo...
#     # Não foi possível encontrar a sequência de CharacterStyleRange contendo 'Produktinformation'
#    -> Encontrado placeholder 'Produktinformation' em 'Story_u15c.xml'. Substituindo...
#     * Substituído e consolidado: 'Produktinformation' -> 'Produktänderung CryoPure Röhren'
#    -> Encontrado placeholder 'Kundenkreis' em 'Story_u90c.xml'. Substituindo...
#     * Substituído e consolidado: 'Kundenkreis' -> 'Übersicht Kundenkreis und
#
# Schlagwörter'
#    -> Encontrado placeholder 'Produktinformation' em 'Story_u67d.xml'. Substituindo...
#     # Não foi possível encontrar a sequência de CharacterStyleRange contendo 'Produktinformation'
#    -> Erro ao processar o arquivo Story_ue90.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3a2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u852.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u868.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1c6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub0d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u90c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u212.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud1c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udec.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u336.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2e6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1f4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u67d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc80.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u63e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1dc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u748.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u58d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua10.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua68.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua26.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u498.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u894.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf5d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue20.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u93f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9b3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u75e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc58.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u482.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9fa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u805.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u798.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u146.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u533.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u426.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u54a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7ca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue37.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue7a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud72.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u654.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uef6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u922.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u60f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u352.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf1e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub31.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucc4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2cc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5b9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uae1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uba3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u96d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u628.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4db.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u560.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uebe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6b7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u83c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u31c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u87e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub5f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u172.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue03.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u983.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue4d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u262.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub76.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud56.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u36c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua3c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u456.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u700.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud06.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufcd.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u576.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud32.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u22c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufa0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8aa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4ae.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u507.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u386.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u955.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaa2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u193.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf8a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u99d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u27c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubfe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucf0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u440.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc97.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub8d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u246.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u15c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufb7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1b0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8c0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7e1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ueda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ube6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5a3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubb9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udd6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud89.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5f9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf74.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4f1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaf7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6e9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5d1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc34.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6d3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7b4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua52.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u296.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9ce.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u51d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4c4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubd0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3bc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u774.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u302.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uff1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uea6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3f2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2b2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u46c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf46.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3d6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue64.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc1a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u724.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u822.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u40c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u69e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua7e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Encontrado placeholder 'SARSTEDT' em 'Story_ucc4.xml'. Substituindo...
#     * Substituído e consolidado: 'SARSTEDT' -> 'SARSTEDT'
#    -> Encontrado placeholder 'Nur zum internen Gebrauch' em 'Story_u1f4.xml'. Substituindo...
#     * Substituído e consolidado: 'Nur zum internen Gebrauch' -> '+++ Nur zum internen Gebrauch +++'
#    -> Encontrado placeholder 'Beschreibung & Vorteile' em 'Story_u212.xml'. Substituindo...
#    -> Erro ao processar o arquivo Story_u212.xml: 'NoneType' object has no attribute 'split'
#    -> Encontrado placeholder 'Beschreibung & Vorteile' em 'Story_u22c.xml'. Substituindo...
#    -> Erro ao processar o arquivo Story_u22c.xml: 'NoneType' object has no attribute 'split'
#    -> Encontrado placeholder 'Beschreibung & Vorteile' em 'Story_u246.xml'. Substituindo...
#    -> Erro ao processar o arquivo Story_u246.xml: 'NoneType' object has no attribute 'split'
#    -> Encontrado placeholder 'Beschreibung & Vorteile' em 'Story_u5f9.xml'. Substituindo...
#    -> Erro ao processar o arquivo Story_u5f9.xml: 'NoneType' object has no attribute 'split'
#    -> Encontrado placeholder 'Produktinformation' em 'Story_u67d.xml'. Substituindo...
#     # Não foi possível encontrar a sequência de CharacterStyleRange contendo 'Produktinformation'
#    -> Erro ao processar o arquivo Story_ue90.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3a2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u852.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u868.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1c6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub0d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u90c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u212.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud1c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udec.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u336.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2e6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1f4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u67d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc80.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u63e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1dc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u748.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u58d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua10.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua68.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua26.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u498.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u894.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf5d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue20.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u93f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9b3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u75e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc58.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u482.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9fa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u805.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u798.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u146.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u533.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u426.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u54a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7ca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue37.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue7a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud72.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u654.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uef6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u922.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u60f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u352.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf1e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub31.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucc4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2cc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5b9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uae1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uba3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u96d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u628.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4db.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u560.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uebe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6b7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u83c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u31c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u87e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub5f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u172.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue03.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u983.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue4d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u262.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub76.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud56.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u36c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua3c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u456.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u700.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud06.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufcd.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u576.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud32.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u22c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufa0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8aa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4ae.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u507.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u386.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u955.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaa2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u193.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf8a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u99d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u27c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubfe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucf0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u440.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc97.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub8d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u246.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u15c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufb7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1b0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8c0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7e1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ueda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ube6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5a3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubb9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udd6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud89.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5f9.xml: 'in <string>' requires string as left operand, not NoneType
# ...
#    -> Erro ao processar o arquivo Story_ub0d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u90c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u212.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud1c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udec.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u336.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2e6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1f4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u67d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc80.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u63e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1dc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u748.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u58d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua10.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua68.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua26.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u498.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u894.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf5d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue20.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u93f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9b3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u75e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc58.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u482.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9fa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u805.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u798.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u146.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u533.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u426.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u54a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7ca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue37.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue7a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud72.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u654.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uef6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u922.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u60f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u352.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf1e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub31.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucc4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2cc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5b9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uae1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uba3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u96d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u628.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9e4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4db.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u560.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uebe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6b7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u83c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u31c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u87e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub5f.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u172.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue03.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u983.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue4d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u262.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub76.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud56.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u36c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua3c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u456.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u700.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud06.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufcd.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u576.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud32.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u22c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufa0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8aa.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4ae.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u507.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u386.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u955.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaa2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u193.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf8a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u99d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u27c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubfe.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucf0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u440.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc97.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ub8d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u246.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u15c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ufb7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u1b0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u8c0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7e1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ueda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ube6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5a3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubb9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udd6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_udad.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ud89.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5f9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf74.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4f1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaf7.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uaca.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ucda.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6e9.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u5d1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc34.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u6d3.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u7b4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua52.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u296.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u9ce.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u51d.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u4c4.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ubd0.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3bc.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u774.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u302.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uff1.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uea6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3f2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u2b2.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u46c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uf46.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u3d6.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ue64.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_uc1a.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u724.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u822.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u40c.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_u69e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Erro ao processar o arquivo Story_ua7e.xml: 'in <string>' requires string as left operand, not NoneType
#    -> Encontrado placeholder 'SARSTEDT' em 'Story_ucc4.xml'. Substituindo...
#     * Substituído e consolidado: 'SARSTEDT' -> 'SARSTEDT'
#    -> Encontrado placeholder 'Nur zum internen Gebrauch' em 'Story_u1f4.xml'. Substituindo...
#     * Substituído e consolidado: 'Nur zum internen Gebrauch' -> '+++ Nur zum internen Gebrauch +++'
# ✅ 57 substituições de conteúdo realizadas com sucesso.

# %% [markdown]
# ### Image Replacement

# %%
# Processamento de PDF
import fitz  # PyMuPDF - já em uso
# import PyPDF2  # Alternativa para metadados

# Processamento de imagens
from PIL import Image
import cv2  # Para transformações avançadas

# IDML
import xml.etree.ElementTree as ET
import zipfile  # IDML são arquivos ZIP
import uuid  # Para IDs únicos

# IA e análise
import google.generativeai as genai  # Já em uso
import json

# Para trabalhar com IDML de forma mais robusta
# pip install idml-tools
from idml import IDML

# Para análise de layout mais avançada
# pip install layoutparser
import layoutparser as lp

# %%
def enhanced_image_analysis(pdf_old_path: str, pdf_new_path: str) -> dict:
    # Adicionar às informações retornadas:
    return {
        'page_num': page_num,
        'old_images': [...],
        'new_images': [...],
        'comparison_summary': "...",
        'action': 'migrate|non-migrate',
        # NOVOS CAMPOS:
        'image_coordinates': {
            'old': [(x, y, width, height), ...],
            'new': [(x, y, width, height), ...]
        },
        'image_properties': {
            'old': [{'dpi': 300, 'format': 'jpeg', 'size_kb': 150}, ...],
            'new': [{'dpi': 300, 'format': 'png', 'size_mb': 2.1}, ...]
        },
        'migration_mapping': [
            {'old_index': 0, 'new_index': 1, 'confidence': 0.85}
        ]
    }

# %%
def extract_pdf_structure(pdf_path: str) -> dict:
    """Extrai estrutura completa do PDF incluindo textos, imagens e layout"""
    return {
        'pages': [
            {
                'page_num': 0,
                'dimensions': (width, height),
                'images': [
                    {
                        'bbox': (x0, y0, x1, y1),
                        'image_data': base64_data,
                        'properties': {...}
                    }
                ],
                'text_blocks': [
                    {
                        'bbox': (x0, y0, x1, y1),
                        'text': "conteúdo",
                        'font': "Arial",
                        'size': 12
                    }
                ]
            }
        ]
    }

# %%
def process_migration_images(analysis_result: dict) -> dict:
    """Processa imagebs marcadas para migração"""
    processed_images = {}
    
    for page_num, page_data in analysis_result.items():
        if page_data.get('action') == 'migrate':
            # Extrair imagens do PDF antigo
            # Otimizar qualidade/formato se necessário
            # Preparar para inserção no IDML
            processed_images[page_num] = {
                'source_images': extract_images_from_old_pdf(),
                'target_positions': get_new_pdf_positions(),
                'transformations': calculate_scaling_rotation()
            }
    
    return processed_images

# %%
def prepare_idml_structure(new_template_dir: str, migrated_dir: str) -> str:
    """
    Prepara estrutura IDML copiando template e limpando migração anterior
    Similar ao processo atual para textos, mas adaptado para imagens
    """
    import shutil
    from pathlib import Path
    
    migrated_path = Path(migrated_dir)
    new_template_path = Path(new_template_dir)
    
    # Limpeza do diretório anterior (igual ao processo atual)
    if migrated_path.exists():
        print(f"🧹 Limpando diretório de migração anterior: '{migrated_dir}'")
        shutil.rmtree(migrated_path)
    
    # Cópia do template (igual ao processo atual)
    print(f"©️ Copiando template de '{new_template_dir}' para '{migrated_dir}'...")
    shutil.copytree(new_template_path, migrated_path)
    
    # Verificar se é um IDML válido (descompactar se necessário)
    if new_template_path.suffix.lower() == '.idml':
        # Se o template é um arquivo IDML, descompactar
        idml_extracted = migrated_path / "idml_extracted"
        with zipfile.ZipFile(new_template_path, 'r') as zip_ref:
            zip_ref.extractall(idml_extracted)
        return str(idml_extracted)
    else:
        # Se já é um diretório descompactado
        return str(migrated_path)

def create_idml_structure(template_path: str, output_dir: str) -> dict:
    """
    Cria estrutura IDML baseada em template existente
    Retorna caminhos para os diretórios principais
    """
    # Preparar estrutura baseada no template
    working_dir = prepare_idml_structure(template_path, output_dir)
    
    return {
        'working_directory': working_dir,
        'spreads_dir': os.path.join(working_dir, 'Spreads'),
        'stories_dir': os.path.join(working_dir, 'Stories'),
        'resources_dir': os.path.join(working_dir, 'Resources'),
        'links_dir': os.path.join(working_dir, 'Links'),  # Para imagens externas
        'designmap_path': os.path.join(working_dir, 'designmap.xml'),
        'preferences_path': os.path.join(working_dir, 'preferences.xml')
    }

# %%
def migrate_images_to_idml_template(idml_structure: dict, processed_images: dict, image_placeholders: dict) -> int:
    """
    Migra imagens para template IDML seguindo padrão similar ao replace_and_consolidate_content
    
    Args:
        idml_structure: Estrutura de diretórios do IDML
        processed_images: Imagens processadas para migração  
        image_placeholders: Dicionário com placeholders de imagem no template
        
    Returns:
        Número de imagens migradas com sucesso
    """
    spreads_dir = idml_structure['spreads_dir']
    links_dir = idml_structure['links_dir']
    
    # Criar diretório Links se não existir (para imagens externas)
    os.makedirs(links_dir, exist_ok=True)
    
    sucessos = 0
    print("🖼️  Iniciando a migração de imagens para o template IDML...")
    
    for page_num, image_data in processed_images.items():
        if image_data.get('action') == 'migrate':
            for image_info in image_data.get('images_to_migrate', []):
                placeholder_id = image_info.get('placeholder_id')  # ex: "IMAGE_PLACEHOLDER_001"
                image_content = image_info.get('image_data')
                image_filename = image_info.get('filename', f'migrated_image_{page_num}_{sucessos}.jpg')
                
                # Salvar imagem no diretório Links
                image_path = os.path.join(links_dir, image_filename)
                save_image_to_file(image_content, image_path)
                
                # Substituir placeholder nos arquivos Spread
                if replace_image_placeholder(placeholder_id, image_filename, spreads_dir):
                    sucessos += 1
                    print(f"✅ Imagem migrada: {image_filename} -> {placeholder_id}")
                else:
                    print(f"⚠️ Falha ao migrar imagem: {placeholder_id}")
    
    return sucessos

def replace_image_placeholder(placeholder_id: str, image_filename: str, spreads_dir: str) -> bool:
    """
    Substitui placeholder de imagem nos arquivos XML do Spread
    Similar ao replace_and_consolidate_content mas para imagens
    """
    try:
        # Percorrer todos os arquivos .xml na pasta Spreads
        for spread_file in Path(spreads_dir).glob("*.xml"):
            tree = ET.parse(spread_file)
            root = tree.getroot()
            
            # Procurar por elementos Image ou Rectangle com o placeholder
            for elem in root.iter():
                # Verificar se elemento contém o placeholder
                if placeholder_id in str(elem.attrib.get('href', '')):
                    # Atualizar referência para nova imagem
                    elem.set('href', f'file://Links/{image_filename}')
                    
                    # Salvar alterações
                    tree.write(spread_file, encoding='utf-8', xml_declaration=True)
                    return True
                    
        return False
    except Exception as e:
        print(f"❌ Erro ao substituir placeholder {placeholder_id}: {e}")
        return False

def save_image_to_file(image_data, output_path: str):
    """Salva dados de imagem em arquivo"""
    if isinstance(image_data, str):  # Base64
        import base64
        with open(output_path, 'wb') as f:
            f.write(base64.b64decode(image_data))
    else:  # Dados binários diretos
        with open(output_path, 'wb') as f:
            f.write(image_data)

# %%
def migrate_pdf_images_to_idml(pdf_old_path: str, pdf_new_path: str, 
                               new_template_path: str, migrated_output_path: str):
    """
    Função principal que orquestra todo o processo seguindo o padrão atual de migração
    """
    
    # Etapa 1: Análise de imagens (sua função atual)
    print("🔍 Iniciando análise de imagens entre PDFs...")
    analysis_result = ai_doc_image_analysis(pdf_old_path, pdf_new_path)
    
    if not analysis_result:
        print("❌ Falha na análise de imagens.")
        return
    
    # Etapa 2: Preparação da estrutura IDML (baseada no seu processo atual)
    print("📁 Preparando estrutura IDML...")
    idml_structure = create_idml_structure(new_template_path, migrated_output_path)
    
    # Etapa 3: Processamento de imagens para migração
    print("🖼️  Processando imagens para migração...")
    processed_images = process_migration_images(analysis_result, pdf_old_path)
    
    # Etapa 4: Migração das imagens (similar ao replace_and_consolidate_content)
    print("✍️  Iniciando a migração de imagens para o template...")
    image_placeholders = detect_image_placeholders(idml_structure)
    sucessos = migrate_images_to_idml_template(idml_structure, processed_images, image_placeholders)
    
    # Etapa 5: Finalização (similar ao seu processo atual)
    if sucessos > 0:
        print(f"✅ {sucessos} imagens migradas com sucesso.")
        
        # Compactar de volta para IDML
        final_idml_path = f"{migrated_output_path}.idml"
        compress_to_idml(idml_structure['working_directory'], final_idml_path)
        print(f"📦 Arquivo IDML final gerado: {final_idml_path}")
        
    else:
        print("⚠️ Nenhuma imagem foi migrada. Verifique os placeholders de imagem.")

def compress_to_idml(working_dir: str, output_idml_path: str):
    """Compacta diretório de trabalho de volta para arquivo IDML"""
    with zipfile.ZipFile(output_idml_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(working_dir):
            for file in files:
                file_path = os.path.join(root, file)
                arc_name = os.path.relpath(file_path, working_dir)
                zipf.write(file_path, arc_name)

def detect_image_placeholders(idml_structure: dict) -> dict:
    """
    Detecta placeholders de imagem no template IDML
    Retorna mapeamento de placeholders encontrados
    """
    placeholders = {}
    spreads_dir = idml_structure['spreads_dir']
    
    for spread_file in Path(spreads_dir).glob("*.xml"):
        tree = ET.parse(spread_file)
        root = tree.getroot()
        
        # Procurar por elementos com referências que parecem placeholders
        for elem in root.iter():
            href = elem.attrib.get('href', '')
            if 'PLACEHOLDER' in href.upper() or 'IMAGE_' in href.upper():
                placeholders[href] = spread_file.name
                
    return placeholders

# %%
migrate_pdf_images_to_idml(
    pdf_old_path=pdf_old_path,
    pdf_new_path=pdf_new_path,
    new_template_path=f"./{idml_final_path}",  # ou diretório descompactado
    migrated_output_path=migrated_dir  # será criado automaticamente
)
# Out:
# 🔍 Iniciando análise de imagens entre PDFs...
# Warning: Documents have different page counts. Comparison will be limited.
# Analyzing images on page 0...
# >>> Image Analysis Result (Page 1):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image displays a product information page for 'CryoPure Röhren' (CryoPure Tubes). It features several vials with different colored caps and varying levels of red liquid inside, arranged in a row. The vials are the main focus, and the background is plain white. Text elements include the product name, a product information number (958/72/0823), and the name of a product manager (Susanne Baß). The Sarstedt logo and website address are also present."
#     ],
#     "new_images": [
#       "The image displays a product information page featuring a row of 'Kleinvolumige S-Monovette® 1,6 ml Serum CAT / Lithium-Heparin LH' tubes. These tubes have different colored caps and labels, and they contain varying levels of liquid. The background is a light gradient. Text elements include the product name, the Sarstedt logo, a product information number (990), and the name of a product manager (Dr. Christa Seipelt). The text 'Neuprodukt' and 'März 2025' are also present."
#     ],
#     "comparison_summary": "The old image shows 'CryoPure Röhren' tubes, while the new image shows 'Kleinvolumige S-Monovette®' tubes. Both images display product information and feature a row of vials with different colored caps. The overall style and layout are different, with the new image having a more modern and professional appearance. The products are different, so the image is not a direct replacement.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 1...
# >>> Image Analysis Result (Page 2):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image is a table of contents for a product change document, specifically for CryoPure tubes. It is divided into sections such as product change details, description and benefits, positioning and customers, product data and ordering information, marketing materials, competitor information, packaging and instructions, and background information and literature. Each section has subsections with specific topics. The document also includes the company's logo (Sarstedt) and website address."
#     ],
#     "new_images": [
#       "The image is a table of contents for product information, specifically for Kleinvolumige S-Monovette 1.6 ml serum CAT / Lithium-Heparin LH. It is divided into sections such as description and benefits, positioning and customers, product data and ordering information, communications media for sales support, competitor information, packaging and instructions, and background information and literature. Each section has subsections with specific topics. The document also includes the company's logo (Sarstedt)."
#     ],
#     "comparison_summary": "The images are both tables of contents for product information documents. The old document is for CryoPure tubes, while the new document is for Kleinvolumige S-Monovette. Both tables of contents are divided into similar sections, such as description and benefits, positioning and customers, product data and ordering information, competitor information, packaging and instructions, and background information and literature. However, the new document includes a section on communications media for sales support, which is not present in the old document. The layout and design of the tables of contents are also different, with the new document having a more modern and streamlined design.",
#     "action": "migrate"
#   }
# }
# Analyzing images on page 2...
# >>> Image Analysis Result (Page 3):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image is a screenshot of a webpage or document related to CryoPure tubes. It includes a navigation bar at the top with sections like 'Produktanderung', 'Beschreibung & Vorteile', etc. The main content describes the features and benefits of CryoPure tubes, mentioning that they are DNA-/DNase- and RNase-free certified. It also includes information about availability and ordering. A circular badge with 'Cryo Performance Tested' is visible on the right side, along with the Sarstedt logo at the bottom."
#     ],
#     "new_images": [
#       "The image is a screenshot of a product information page, likely from Sarstedt. It focuses on 'kleinvolumige S-Monovette' tubes. The page includes sections describing the product's purpose, features, and benefits. There are bullet points highlighting characteristics like small volume, standard dimensions, and automatic processing. Small images of the tubes are shown on the bottom right."
#     ],
#     "comparison_summary": "The old image focuses on CryoPure tubes, highlighting their certification and availability. The new image focuses on 'kleinvolumige S-Monovette' tubes, detailing their features and benefits. The images are different products and different layouts.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 3...
# >>> Image Analysis Result (Page 4):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a product page for CryoPure tubes. It includes text in German describing the product's features and applications. There is a diagram illustrating four different configurations of the CryoPure tubes. The page also includes the company logo (Sarstedt) and navigation elements indicating it's part of a larger document."
#     ],
#     "new_images": null,
#     "comparison_summary": "The old document page contains an image of a product page for CryoPure tubes, including text, diagrams, and the company logo. The new document page does not contain any images.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 4...
# >>> Image Analysis Result (Page 5):
# {
#   "image_analysis": {
#     "old_images": [
#       "A product presentation page with text in German. It features multiple images of CryoPure tubes with different colored caps, showcasing various volumes and applications. The Sarstedt logo is present at the bottom right."
#     ],
#     "new_images": [
#       "A product information page with the Sarstedt logo at the top left. It features images of S-Monovette tubes with different colored caps, showcasing various volumes and applications. Arrows indicate percentage increases. Text in German describes the products and provides article numbers."
#     ],
#     "comparison_summary": "The old document shows CryoPure tubes, while the new document shows S-Monovette tubes. Both documents showcase tubes with different colored caps and volumes, but the specific products and presentation styles differ. The new document includes percentage increase indicators and article numbers, which are absent in the old document.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 5...
# >>> Image Analysis Result (Page 6):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a product information page for CryoPure tubes from Sarstedt. It includes the product name, a diagram of the tube, and text describing the features and benefits of the product. There are also several logos and certifications displayed."
#     ],
#     "new_images": [
#       "The image shows a product information page for Sarstedt, focusing on the benefits and uses of Patient Blood Management (PBM) concepts. It presents a table outlining different scenarios, target groups, advantages for the application site, and advantages for the patient. The table is divided into three scenarios, each detailing a specific aspect of PBM. The page also includes the Sarstedt logo and a product information header."
#     ],
#     "comparison_summary": "The old image is a product page for CryoPure tubes, while the new image is a product page focusing on Patient Blood Management (PBM) concepts. The content, product focus, and layout are entirely different. The old image features a product diagram and specific product details, while the new image uses a table to explain different scenarios and benefits related to PBM.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 6...
# >>> Image Analysis Result (Page 7):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image is a table titled 'Tabelle 2' which lists different institutions (Ärzte, Diagnostische Labore, Industrie, Krankenhäuser, Universitäten, Universitätskliniken) along with their general direction (Richtung allgemein), specific direction/institute (Richtung speziell / Institute), and keywords (Schlagwörter). The table is part of a document related to 'Produktänderung CryoPure Röhren'. The document also contains a header with navigation links and a footer with the company logo (SARSTEDT) and a statement '+++ Nur zum internen Gebrauch +++'."
#     ],
#     "new_images": [
#       "The image shows four different sizes of S-Monovette tubes (7.5 ml, 4.0 ml, 2.7 ml, and 1.6 ml) with varying levels of blood samples. The image includes text indicating the percentage less of the sample in each tube compared to the largest tube (7.5 ml). The image also contains product information, article numbers, and ISO Farbcode information. The SARSTEDT logo is present at the top left, and the phrase '/// Nur zum internen Gebrauch ///' is at the bottom right."
#     ],
#     "comparison_summary": "The old image is a table describing institutions and keywords related to CryoPure tubes, while the new image showcases different sizes of S-Monovette tubes with varying blood sample levels and product information. The images are completely different in content and purpose. The old image is informational and tabular, while the new image is a product display with technical details.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 7...
# >>> Image Analysis Result (Page 8):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image displays a product catalog page with a table detailing various CryoPure tubes. The table includes columns for order number, description, color coding, nominal volume, type, sterility, pyrogen/cytotoxin status, DNase/RNase-free status, material (tube/cap), holding capacity (vials), packaging, and availability date. The page also includes the company logo and website address."
#     ],
#     "new_images": [
#       "The image displays a product information page with the company logo at the top left. The page is divided into sections focusing on customer positioning and product positioning. It lists various customer types such as hospitals and laboratories, and discusses the product's positioning for pediatric probes and patient blood management. The page also includes a section on potential customers and a footer indicating internal use."
#     ],
#     "comparison_summary": "The old document page features a product catalog with a detailed table of CryoPure tubes, while the new document page presents product information focusing on customer and product positioning. The images are completely different in content and purpose. The old image is a product specification table, while the new image is marketing and customer-focused information.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 8...
# >>> Image Analysis Result (Page 9):
# {
#   "image_analysis": {
#     "old_images": [
#       "A table displaying product information for CryoPure tubes, including details such as part number, description, color, nominal volume, centrifuged, sterile, pyrogen-free, DNase/RNase-free, material, Halbarkeit (months), packaging, and availability date. The table is well-structured with clear headings and data entries."
#     ],
#     "new_images": [
#       "A table displaying product information, including details such as product name, product features, volume, color, barcode, sterile, lot number, certification, centrifugation conditions, blood sample volume, packaging, and availability. The table is well-structured with clear headings and data entries."
#     ],
#     "comparison_summary": "The old image shows a product table for CryoPure tubes, while the new image shows a product table with different products and different columns. The structure is similar, but the content and specific details differ significantly.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 9...
# >>> Image Analysis Result (Page 10):
# {
#   "image_analysis": {
#     "old_images": [
#       "A table of product and ordering information for CryoPure tubes, including columns for Best.-Nr., Farbe, Gewichtstyp, Material, Haltbarkeit, Verpackung, Empf. VE, and Verfügbar seit.",
#       "A table of product and ordering information for CryoRack 40/Arbeitsrack, including columns for Best.-Nr., Kapazität, Verpackung, Empf. VE, and Verfügbar seit.",
#       "A photograph of various colored tubes in a rack.",
#       "The Sarstedt logo."
#     ],
#     "new_images": [
#       "The Sarstedt logo.",
#       "A photograph of a person using a laptop displaying a graph and text about 'Proven millions of times over, safe and efficient!' and 'The Industry standard'.",
#       "A photograph of a woman sitting at a table."
#     ],
#     "comparison_summary": "The old document contains tables of product information and a photo of tubes, while the new document features the Sarstedt logo, a person using a laptop, and a woman at a table. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 10...
# >>> Image Analysis Result (Page 11):
# {
#   "image_analysis": {
#     "old_images": [
#       "The image shows a table with product and ordering information for cryoboxes. The table includes columns for part number, suitable for cryoboxes, raster size, storage capacity, outer dimensions, material, color, packaging, and expiration date. To the right of the table is an image of cryoboxes filled with tubes."
#     ],
#     "new_images": [
#       "The image shows a table with competitor information. The table includes columns for company name, description, color code, and order number."
#     ],
#     "comparison_summary": "The old image shows a table of product information for cryoboxes, while the new image shows a table of competitor information. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 11...
# >>> Image Analysis Result (Page 12):
# {
#   "image_analysis": {
#     "old_images": [
#       "A product page with the title 'Produktanderung CryoPure Rohren'. It features a navigation bar at the top, a website link, and a section for brochures. A prominent image shows a 'Cell and tissue culture' container with the text 'Come Grow With Us'. A table lists different languages with corresponding PDF download options. The Sarstedt logo is at the bottom."
#     ],
#     "new_images": [
#       "A product information page with the Sarstedt logo at the top left and 'Produktinformation' at the top right. The page features a table comparing the 'Eigenschaften und Vorteile Mitbewerberprodukte' (features and benefits of competitor products) for 'Kleinvolumige S-Monovette' 1.6 ml serum CAT / Lithium-Heparin LH'. The table lists various features and compares Sarstedt's product with competitors like Becton Dickinson, Greiner Bio-One, KOMA, and KABE."
#     ],
#     "comparison_summary": "The old image is a product page focused on 'CryoPure Rohren' with an emphasis on cell and tissue culture, featuring a specific product image and language-specific brochure downloads. The new image is a product information page comparing Sarstedt's 'S-Monovette' with competitor products based on various features. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 12...
# >>> Image Analysis Result (Page 13):
# {
#   "image_analysis": {
#     "old_images": [
#       "A product information page with a table listing CryoPure freezing system information in multiple languages, along with a product image showing tubes and a freezing system."
#     ],
#     "new_images": [
#       "Illustrations of packaging options (Umverpackung, Innenkarton, Umkarton, Palette) with corresponding quantities of S-Monovette products. Also includes a QR code and diagrams illustrating usage instructions."
#     ],
#     "comparison_summary": "The old document page features a product information table and an image of the CryoPure freezing system. The new document page shows packaging illustrations and usage diagrams for S-Monovette products. The images are completely different in content and purpose.",
#     "action": "non-migrate"
#   }
# }
# Analyzing images on page 13...
# >>> Image Analysis Result (Page 14):
# {
#   "image_analysis": {
#     "old_images": [
#       "Image of a CryoPure Musterset product, showing a box with various tubes inside. The box is white with a red stripe and the tubes are different colors. The image is on the left side of the page."
#     ],
#     "new_images": null,
#     "comparison_summary": "The old document contains an image of a CryoPure Musterset product, while the new document does not contain any images on the corresponding page. The new document contains a table with text.",
#     "action": "non-migrate"
#   }
# }
# 📁 Preparando estrutura IDML...
# 🧹 Limpando diretório de migração anterior: 'data/migrated'
# ©️ Copiando template de './data/migrated.idml' para 'data/migrated'...
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 migrate_pdf_images_to_idml(
#       2     pdf_old_path=pdf_old_path,
#       3     pdf_new_path=pdf_new_path,
#       4     new_template_path=f"./{idml_final_path}",  # ou diretório descompactado
#       5     migrated_output_path=migrated_dir  # será criado automaticamente
#       6 )
#
# Cell In[103], line 17, in migrate_pdf_images_to_idml(pdf_old_path, pdf_new_path, new_template_path, migrated_output_path)
#      15 # Etapa 2: Preparação da estrutura IDML (baseada no seu processo atual)
#      16 print("📁 Preparando estrutura IDML...")
# ---> 17 idml_structure = create_idml_structure(new_template_path, migrated_output_path)
#      19 # Etapa 3: Processamento de imagens para migração
#      20 print("🖼️  Processando imagens para migração...")
#
# Cell In[101], line 38, in create_idml_structure(template_path, output_dir)
#      33 """
#      34 Cria estrutura IDML baseada em template existente
#      35 Retorna caminhos para os diretórios principais
#      36 """
#      37 # Preparar estrutura baseada no template
# ---> 38 working_dir = prepare_idml_structure(template_path, output_dir)
#      40 return {
#      41     'working_directory': working_dir,
#      42     'spreads_dir': os.path.join(working_dir, 'Spreads'),
#    (...)     47     'preferences_path': os.path.join(working_dir, 'preferences.xml')
#      48 }
#
# Cell In[101], line 19, in prepare_idml_structure(new_template_dir, migrated_dir)
#      17 # Cópia do template (igual ao processo atual)
#      18 print(f"©️ Copiando template de '{new_template_dir}' para '{migrated_dir}'...")
# ---> 19 shutil.copytree(new_template_path, migrated_path)
#      21 # Verificar se é um IDML válido (descompactar se necessário)
#      22 if new_template_path.suffix.lower() == '.idml':
#      23     # Se o template é um arquivo IDML, descompactar
#
# File /nix/store/mh6gqjf1w1i6ln1a61psnz0gzdmwrspl-python3-3.11.8/lib/python3.11/shutil.py:571, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     532 """Recursively copy a directory tree and return the destination directory.
#     533
#     534 If exception(s) occur, an Error is raised with a list of reasons.
#    (...)    568 `src` tree.
#     569 """
#     570 sys.audit("shutil.copytree", src, dst)
# --> 571 with os.scandir(src) as itr:
#     572     entries = list(itr)
#     573 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     574                  ignore=ignore, copy_function=copy_function,
#     575                  ignore_dangling_symlinks=ignore_dangling_symlinks,
#     576                  dirs_exist_ok=dirs_exist_ok)
#
# NotADirectoryError: [Errno 20] Not a directory: 'data/migrated.idml'

# %% [markdown]
# ## IDML Export

# %%
def criar_pacote_idml(source_dir: Path, output_filename: str):
    """Cria um arquivo .idml (zip) a partir de um diretório de origem."""
    print(f"📦 Empacotando o resultado em '{output_filename}'...")
    with zipfile.ZipFile(output_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(source_dir):
            for file in files:
                file_path = Path(root) / file
                # O caminho no arquivo zip deve ser relativo ao diretório de origem
                archive_name = file_path.relative_to(source_dir)
                zipf.write(file_path, archive_name)
    print(f"Pacote '{output_filename}' criado com sucesso!")

# %%
# 7. Empacotar o resultado final em um novo arquivo .idml
criar_pacote_idml(migrated_dir, idml_final_path)

print("\n🎉 Processo de migração concluído!")
print(f"Seu novo documento está pronto em: ./{idml_final_path}")
print("Abra este arquivo no Adobe InDesign para verificar e exportar como PDF.")
# Out:
# 📦 Empacotando o resultado em 'data/migrated.idml'...
# Pacote 'data/migrated.idml' criado com sucesso!
#
# 🎉 Processo de migração concluído!
# Seu novo documento está pronto em: ./data/migrated.idml
# Abra este arquivo no Adobe InDesign para verificar e exportar como PDF.
